# %%
from scipy.io import loadmat

# %%
import h5py
with h5py.File('/Users/chuansun/Desktop/cnv_p06_wav_trialavg.mat', 'r') as f:
    print(f)
# Out:
# <HDF5 file "cnv_p06_wav_trialavg.mat" (mode r)>
