# %%
import pandas as pd
import numpy as np
import mat73

# %%
data_dict = mat73.loadmat('wireless_dataset.mat')

# %%
data = []
for row in data_dict['wireless_dataset'][0]['user']:
    data.append([row['channel'], row['loc']])

df = pd.DataFrame(data, columns=["channel", "loc"])
df
#data_dict['wireless_dataset'][0]['user'][0]
# Out:
#                                                 channel                    loc
# 0     [[(-6.51345622536489e-07-8.999511248733736e-07...       [0.0, 9.0, 1.25]
# 1     [[(-6.863152455112058e-07+4.324723224630128e-0...   [0.08979, 9.0, 1.25]
# 2     [[(-4.792217465216584e-07+1.4013535244935746e-...   [0.17958, 9.0, 1.25]
# 3     [[(-1.4302138273037174e-06-2.3716449564022114e...   [0.26937, 9.0, 1.25]
# 4     [[(-4.305048877034539e-06+1.3828859705182114e-...   [0.35916, 9.0, 1.25]
# ...                                                 ...                    ...
# 4995  [[(-7.13155916861366e-07+6.610069994295831e-07...   [89.341, 11.0, 1.25]
# 4996  [[(6.115357036582061e-08-6.11069346488476e-07j...  [89.4308, 11.0, 1.25]
# 4997  [[(-2.559131822212521e-07+6.833053948388901e-0...  [89.5206, 11.0, 1.25]
# 4998  [[(-4.7265781422841377e-07-8.786025743629012e-...  [89.6104, 11.0, 1.25]
# 4999  [[(7.649440649255459e-07+1.8434482116471565e-0...  [89.7002, 11.0, 1.25]
#
# [5000 rows x 2 columns]

# %%
aa=data_dict['wireless_dataset'][0]['user'][0]["channel"]
len(aa)
# Out:
# 128

# %%
aa
# Out:
# array([[-6.51345623e-07-8.99951125e-07j, -6.36677845e-07+1.67226770e-06j,
#          2.40391156e-06-1.49613013e-07j, ...,
#          1.38506781e-06+1.48336437e-06j,  3.41396570e-07-1.23032165e-06j,
#         -5.45153823e-07+5.34421938e-07j],
#        [-1.09585459e-06+2.23096093e-06j,  1.46733793e-06+1.25690290e-06j,
#          1.94441136e-06-9.57859538e-07j, ...,
#         -8.96954232e-07-1.59273688e-06j, -1.91441837e-06+1.18374306e-07j,
#         -4.15273482e-07+2.76656368e-06j],
#        [-1.53375958e-06+2.88992153e-06j,  2.71610315e-06+6.28603620e-07j,
#         -4.34428718e-08-1.97763241e-06j, ...,
#         -2.39912171e-06-4.17587979e-06j, -3.32715463e-06+2.31395999e-06j,
#          1.66093750e-06+2.68456660e-06j],
#        ...,
#        [-1.14206257e-06-1.59087300e-06j, -1.54870552e-06+1.75100932e-06j,
#          2.08843023e-06+9.42911858e-07j, ...,
#          3.59369658e-06-2.58487195e-06j, -3.26894153e-06-3.56199876e-06j,
#         -2.95027794e-06+3.69047877e-06j],
# ...

# %%
len(aa[0])
# Out:
# 32

# %%
aa[0]
# Out:
# array([-6.51345623e-07-8.99951125e-07j, -6.36677845e-07+1.67226770e-06j,
#         2.40391156e-06-1.49613013e-07j, -1.11137857e-06-2.55971770e-06j,
#        -2.16852889e-06+1.80045747e-06j,  1.91238918e-06+1.55758208e-06j,
#         1.17231012e-06-1.45223847e-06j, -7.31263595e-07-1.33149577e-06j,
#        -2.05166910e-06+1.96256153e-07j,  1.84870427e-07+3.03677853e-06j,
#         3.83879877e-06-7.40725864e-07j, -1.58938264e-06-4.10147445e-06j,
#        -3.75394146e-06+2.28832731e-06j,  2.46895987e-06+3.04837331e-06j,
#         2.42108245e-06-2.03826792e-06j, -1.22991449e-06-2.25303633e-06j,
#        -2.66074463e-06+4.76801971e-07j,  1.74785489e-07+3.43186661e-06j,
#         4.14075712e-06-4.66725243e-07j, -1.16494512e-06-4.38078207e-06j,
#        -3.98638616e-06+1.85448687e-06j,  2.12069375e-06+3.12349724e-06j,
#         2.19884029e-06-1.77667628e-06j, -9.66277010e-07-1.63774824e-06j,
#        -1.65195762e-06+8.62244206e-08j, -4.29970776e-07+2.12435157e-06j,
# ...

# %%
aa.shape
# Out:
# (128, 32)
