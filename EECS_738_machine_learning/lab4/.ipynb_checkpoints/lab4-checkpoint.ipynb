# %%
from __future__ import print_function

import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import SGD, Adam, Adadelta
from tensorflow.keras.activations import relu
from tensorflow.keras.regularizers import l2
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist, cifar10
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

print("Packages Loaded")
# Out:
# Packages Loaded

# %%
# Lets import our MNIST data like we did in lab 3.
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 3s 0us/step

# %%
(x_train_cifar, y_train_cifar), (x_test_cifar, y_test_cifar) = cifar10.load_data()
a = x_train_cifar.reshape(50000, -1)
a.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 52s 0us/step
# (50000, 3072)

# %%
# Now import Cifar-10 data and process it.
(x_train_cifar, y_train_cifar), (x_test_cifar, y_test_cifar) = cifar10.load_data()
x_train_cifar = x_train_cifar.reshape(50000, -1)
x_test_cifar = x_test_cifar.reshape(10000, -1)
x_train_cifar = x_train_cifar.astype('float32') / 255
x_test_cifar = x_test_cifar.astype('float32') / 255

y_train_cifar = tf.keras.utils.to_categorical(y_train_cifar, 10)
y_test_cifar = tf.keras.utils.to_categorical(y_test_cifar, 10)
input_shape_cifar = x_train_cifar.shape[1:]

# %%
# %%time
# Our baseline model for this lab.
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer=SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True),
              metrics=['accuracy'])
model.fit(x_train, y_train, epochs=20, batch_size=64, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.4140 - acc: 0.8731 - val_loss: 0.1674 - val_acc: 0.9497
# Epoch 2/20
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.1521 - acc: 0.9544 - val_loss: 0.1238 - val_acc: 0.9626
# Epoch 3/20
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.1107 - acc: 0.9662 - val_loss: 0.1071 - val_acc: 0.9655
# Epoch 4/20
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0876 - acc: 0.9724 - val_loss: 0.1027 - val_acc: 0.9680
# Epoch 5/20
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0726 - acc: 0.9772 - val_loss: 0.0955 - val_acc: 0.9705
# Epoch 6/20
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0612 - acc: 0.9807 - val_loss: 0.0902 - val_acc: 0.9731
# Epoch 7/20
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0531 - acc: 0.9827 - val_loss: 0.0935 - val_acc: 0.9710
# Epoch 8/20
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0450 - acc: 0.9859 - val_loss: 0.0836 - val_acc: 0.9759
# Epoch 9/20
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0408 - acc: 0.9866 - val_loss: 0.1110 - val_acc: 0.9686
# Epoch 10/20
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0362 - acc: 0.9885 - val_loss: 0.0971 - val_acc: 0.9722
# Epoch 11/20
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0317 - acc: 0.9900 - val_loss: 0.0899 - val_acc: 0.9754
# Epoch 12/20
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0292 - acc: 0.9901 - val_loss: 0.0959 - val_acc: 0.9731
# Epoch 13/20
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0245 - acc: 0.9922 - val_loss: 0.1298 - val_acc: 0.9690
# Epoch 14/20
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.0244 - acc: 0.9920 - val_loss: 0.0962 - val_acc: 0.9748
# Epoch 15/20
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0191 - acc: 0.9940 - val_loss: 0.1180 - val_acc: 0.9707
# Epoch 16/20
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0208 - acc: 0.9930 - val_loss: 0.1066 - val_acc: 0.9742
# Epoch 17/20
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0172 - acc: 0.9944 - val_loss: 0.1010 - val_acc: 0.9772
# Epoch 18/20
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.0149 - acc: 0.9950 - val_loss: 0.1183 - val_acc: 0.9746
# Epoch 19/20
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0144 - acc: 0.9953 - val_loss: 0.1151 - val_acc: 0.9742
# Epoch 20/20
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0149 - acc: 0.9949 - val_loss: 0.1093 - val_acc: 0.9757
# CPU times: user 1min 31s, sys: 12.6 s, total: 1min 43s
# Wall time: 59.8 s

# %% [markdown]
# ### Now convert this baseline into a Functional Model using keras' Functional Model API.
# https://keras.io/getting-started/functional-api-guide/

# %%
# %%time
# Create the functional Baseline here.
inputs = Input(shape=(784,))
output = Dense(64, activation='relu')(inputs)
output = Dense(64, activation='relu')(output)
output = Dense(64, activation='relu')(output)
output = Dense(64, activation='relu')(output)
predictions = Dense(10, activation='softmax')(output)
model = Model(inputs=inputs, outputs=predictions)
model.compile(optimizer=SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True),
              loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=20, batch_size=64, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.3914 - acc: 0.8826 - val_loss: 0.1861 - val_acc: 0.9440
# Epoch 2/20
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.1473 - acc: 0.9559 - val_loss: 0.1385 - val_acc: 0.9579
# Epoch 3/20
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.1085 - acc: 0.9666 - val_loss: 0.1066 - val_acc: 0.9686
# Epoch 4/20
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0867 - acc: 0.9730 - val_loss: 0.1007 - val_acc: 0.9696
# Epoch 5/20
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0733 - acc: 0.9775 - val_loss: 0.1016 - val_acc: 0.9684
# Epoch 6/20
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0604 - acc: 0.9808 - val_loss: 0.0999 - val_acc: 0.9713
# Epoch 7/20
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0539 - acc: 0.9831 - val_loss: 0.1176 - val_acc: 0.9646
# Epoch 8/20
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0466 - acc: 0.9852 - val_loss: 0.0926 - val_acc: 0.9739
# Epoch 9/20
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0426 - acc: 0.9862 - val_loss: 0.0908 - val_acc: 0.9729
# Epoch 10/20
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0353 - acc: 0.9886 - val_loss: 0.1148 - val_acc: 0.9678
# Epoch 11/20
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.0315 - acc: 0.9903 - val_loss: 0.1122 - val_acc: 0.9735
# Epoch 12/20
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0277 - acc: 0.9909 - val_loss: 0.1173 - val_acc: 0.9714
# Epoch 13/20
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0272 - acc: 0.9906 - val_loss: 0.1045 - val_acc: 0.9736
# Epoch 14/20
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0256 - acc: 0.9915 - val_loss: 0.1104 - val_acc: 0.9748
# Epoch 15/20
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0211 - acc: 0.9931 - val_loss: 0.1075 - val_acc: 0.9746
# Epoch 16/20
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0187 - acc: 0.9936 - val_loss: 0.1057 - val_acc: 0.9747
# Epoch 17/20
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0187 - acc: 0.9937 - val_loss: 0.1207 - val_acc: 0.9743
# Epoch 18/20
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.0163 - acc: 0.9946 - val_loss: 0.1261 - val_acc: 0.9722
# Epoch 19/20
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0168 - acc: 0.9943 - val_loss: 0.1123 - val_acc: 0.9753
# Epoch 20/20
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0136 - acc: 0.9953 - val_loss: 0.1161 - val_acc: 0.9760
# CPU times: user 1min 31s, sys: 12.4 s, total: 1min 44s
# Wall time: 59.5 s

# %% [markdown]
# ### Now we are going to compare our baseline to a shallow ResNet that we talked about in class.
# Pay attention to the changes we have made so far including optimizers, batch size, layer neuron width, and dropout.
# Why did we make these changes?

# %%
# %%time
inputs = tf.keras.Input(shape=(784,), name='img')
x = Dense(128, activation='relu')(inputs)
block_1_output = Dense(128, activation='relu')(x)

x = Dense(128)(block_1_output)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(128)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
block_2_output = tf.keras.layers.add([x, block_1_output])

x = Dense(128)(block_2_output)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(128)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
block_3_output = tf.keras.layers.add([x, block_2_output])

x = Dense(128)(block_3_output)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(128)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
block_4_output = tf.keras.layers.add([x, block_3_output])

x = Dense(128, activation='relu')(block_4_output)
x = Dropout(0.5)(x)
outputs = Dense(10, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs, name='resnet')

model.compile(Adam(amsgrad=True), 'binary_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=128,
          epochs=20,
          validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 11s 186us/step - loss: 0.1767 - acc: 0.9396 - val_loss: 0.0467 - val_acc: 0.9846
# Epoch 2/20
# 60000/60000 [==============================] - 8s 129us/step - loss: 0.0516 - acc: 0.9837 - val_loss: 0.0307 - val_acc: 0.9902
# Epoch 3/20
# 60000/60000 [==============================] - 8s 132us/step - loss: 0.0334 - acc: 0.9897 - val_loss: 0.0231 - val_acc: 0.9925
# Epoch 4/20
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.0260 - acc: 0.9922 - val_loss: 0.0200 - val_acc: 0.9941
# Epoch 5/20
# 60000/60000 [==============================] - 8s 131us/step - loss: 0.0209 - acc: 0.9935 - val_loss: 0.0196 - val_acc: 0.9941
# Epoch 6/20
# 60000/60000 [==============================] - 8s 133us/step - loss: 0.0177 - acc: 0.9947 - val_loss: 0.0206 - val_acc: 0.9937
# Epoch 7/20
# 60000/60000 [==============================] - 8s 135us/step - loss: 0.0151 - acc: 0.9953 - val_loss: 0.0181 - val_acc: 0.9950
# Epoch 8/20
# 60000/60000 [==============================] - 8s 136us/step - loss: 0.0131 - acc: 0.9958 - val_loss: 0.0165 - val_acc: 0.9954
# Epoch 9/20
# 60000/60000 [==============================] - 8s 136us/step - loss: 0.0114 - acc: 0.9964 - val_loss: 0.0168 - val_acc: 0.9958
# Epoch 10/20
# 60000/60000 [==============================] - 8s 138us/step - loss: 0.0101 - acc: 0.9967 - val_loss: 0.0173 - val_acc: 0.9953
# Epoch 11/20
# 60000/60000 [==============================] - 8s 138us/step - loss: 0.0087 - acc: 0.9972 - val_loss: 0.0169 - val_acc: 0.9956
# Epoch 12/20
# 60000/60000 [==============================] - 8s 137us/step - loss: 0.0083 - acc: 0.9973 - val_loss: 0.0146 - val_acc: 0.9960
# Epoch 13/20
# 60000/60000 [==============================] - 8s 137us/step - loss: 0.0076 - acc: 0.9976 - val_loss: 0.0173 - val_acc: 0.9953
# Epoch 14/20
# 60000/60000 [==============================] - 8s 138us/step - loss: 0.0069 - acc: 0.9977 - val_loss: 0.0164 - val_acc: 0.9958
# Epoch 15/20
# 60000/60000 [==============================] - 8s 138us/step - loss: 0.0064 - acc: 0.9979 - val_loss: 0.0168 - val_acc: 0.9957
# Epoch 16/20
# 60000/60000 [==============================] - 8s 139us/step - loss: 0.0060 - acc: 0.9980 - val_loss: 0.0195 - val_acc: 0.9954
# Epoch 17/20
# 60000/60000 [==============================] - 8s 139us/step - loss: 0.0056 - acc: 0.9982 - val_loss: 0.0172 - val_acc: 0.9957
# Epoch 18/20
# 60000/60000 [==============================] - 8s 142us/step - loss: 0.0053 - acc: 0.9983 - val_loss: 0.0196 - val_acc: 0.9955
# Epoch 19/20
# 60000/60000 [==============================] - 8s 138us/step - loss: 0.0043 - acc: 0.9986 - val_loss: 0.0172 - val_acc: 0.9962
# Epoch 20/20
# 60000/60000 [==============================] - 8s 138us/step - loss: 0.0039 - acc: 0.9987 - val_loss: 0.0167 - val_acc: 0.9962
# CPU times: user 6min 10s, sys: 50.5 s, total: 7min 1s
# Wall time: 2min 49s

# %%
plot_model(model, to_file='reports/resnet.png')

# %% [markdown]
# ### Now lets make a deeper ResNet. Make A network with 10 Residual Blocks.
# How does this affect training speed, accuracy, and stability?

# %%
def create_resnet(layers=3, skips=2, input_shape=(784,), neuron=128, lr=1e-3, dropout=0.5):
    inputs = tf.keras.Input(shape=input_shape, name='img')
    x = Dense(neuron, activation='relu')(inputs)
    block_output = Dense(neuron, activation='relu')(x)
    
    for i in range(layers):
        layer = block_output
        for _ in range(skips):
            layer = Dense(neuron)(layer)
            layer = BatchNormalization()(layer)
            layer = Activation('relu')(layer)
            layer = Dropout(dropout)(layer)
        block_output = tf.keras.layers.add([layer, block_output])
    
    x = Dense(neuron, activation='relu')(block_output)
    x = Dropout(dropout)(x)
    outputs = Dense(10, activation='softmax')(x)
    model = tf.keras.Model(inputs, outputs, name='resnet_10')
    optimizer = Adam(amsgrad=True, lr=lr)
    #optimizer = Adadelta(learning_rate=lr)
    model.compile(optimizer, 'binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# %%time
# Create the deep ResNet here.
model = create_resnet(layers=10)
model.fit(x_train, y_train, batch_size=128, epochs=20, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 30s 508us/step - loss: 0.3047 - acc: 0.9035 - val_loss: 0.1608 - val_acc: 0.9345
# Epoch 2/20
# 60000/60000 [==============================] - 20s 325us/step - loss: 0.1191 - acc: 0.9558 - val_loss: 0.0416 - val_acc: 0.9861
# Epoch 3/20
# 60000/60000 [==============================] - 20s 336us/step - loss: 0.0560 - acc: 0.9824 - val_loss: 0.0311 - val_acc: 0.9897
# Epoch 4/20
# 60000/60000 [==============================] - 18s 306us/step - loss: 0.0387 - acc: 0.9882 - val_loss: 0.0251 - val_acc: 0.9923
# Epoch 5/20
# 60000/60000 [==============================] - 18s 304us/step - loss: 0.0311 - acc: 0.9907 - val_loss: 0.0215 - val_acc: 0.9930
# Epoch 6/20
# 60000/60000 [==============================] - 18s 302us/step - loss: 0.0258 - acc: 0.9922 - val_loss: 0.0208 - val_acc: 0.9939
# Epoch 7/20
# 60000/60000 [==============================] - 18s 301us/step - loss: 0.0215 - acc: 0.9935 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 8/20
# 60000/60000 [==============================] - 18s 307us/step - loss: 0.0190 - acc: 0.9941 - val_loss: 0.0181 - val_acc: 0.9944
# Epoch 9/20
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0171 - acc: 0.9948 - val_loss: 0.0177 - val_acc: 0.9946
# Epoch 10/20
# 60000/60000 [==============================] - 20s 335us/step - loss: 0.0151 - acc: 0.9953 - val_loss: 0.0168 - val_acc: 0.9951
# Epoch 11/20
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0136 - acc: 0.9957 - val_loss: 0.0170 - val_acc: 0.9952
# Epoch 12/20
# 60000/60000 [==============================] - 20s 338us/step - loss: 0.0124 - acc: 0.9962 - val_loss: 0.0196 - val_acc: 0.9942
# Epoch 13/20
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0112 - acc: 0.9965 - val_loss: 0.0164 - val_acc: 0.9954
# Epoch 14/20
# 60000/60000 [==============================] - 19s 313us/step - loss: 0.0107 - acc: 0.9967 - val_loss: 0.0169 - val_acc: 0.9952
# Epoch 15/20
# 60000/60000 [==============================] - 20s 341us/step - loss: 0.0093 - acc: 0.9970 - val_loss: 0.0176 - val_acc: 0.9954
# Epoch 16/20
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.0082 - acc: 0.9973 - val_loss: 0.0183 - val_acc: 0.9946
# Epoch 17/20
# 60000/60000 [==============================] - 19s 324us/step - loss: 0.0078 - acc: 0.9975 - val_loss: 0.0167 - val_acc: 0.9958
# Epoch 18/20
# 60000/60000 [==============================] - 19s 318us/step - loss: 0.0073 - acc: 0.9977 - val_loss: 0.0174 - val_acc: 0.9957
# Epoch 19/20
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.0065 - acc: 0.9979 - val_loss: 0.0171 - val_acc: 0.9956
# Epoch 20/20
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0062 - acc: 0.9980 - val_loss: 0.0170 - val_acc: 0.9958
# CPU times: user 14min 55s, sys: 2min 8s, total: 17min 4s
# Wall time: 6min 46s

# %%
plot_model(model, to_file='reports/resnet_10.png')

# %% [markdown]
# ### Now lets mess with the skip connections. We will make two shallow ResNets that have one and three skip connections.

# %%
# Here is a one skip connection block.

x = Dense(128)(block_1_output)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
block_2_output = tf.keras.layers.add([x, block_1_output])

# Here is a two skip connection block.

x = Dense(128)(block_1_output)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(128)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
block_2_output = tf.keras.layers.add([x, block_1_output])

# Here is a three skip connection block.

x = Dense(128)(block_1_output)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(128)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(128)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
block_2_output = tf.keras.layers.add([x, block_1_output])

# %%
# %%time
# Now make a full shallow network with the different sized blocks and compare the models. 
# Resnet with skip 1
resnet_skip1 = create_resnet(layers=3, skips=1)
resnet_skip1.fit(x_train, y_train, batch_size=128, epochs=20, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 13s 208us/step - loss: 0.1143 - acc: 0.9615 - val_loss: 0.0327 - val_acc: 0.9895
# Epoch 2/20
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.0381 - acc: 0.9882 - val_loss: 0.0251 - val_acc: 0.9919
# Epoch 3/20
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.0271 - acc: 0.9918 - val_loss: 0.0202 - val_acc: 0.9936
# Epoch 4/20
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.0213 - acc: 0.9933 - val_loss: 0.0186 - val_acc: 0.9944
# Epoch 5/20
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.0175 - acc: 0.9946 - val_loss: 0.0184 - val_acc: 0.9945
# Epoch 6/20
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.0150 - acc: 0.9953 - val_loss: 0.0183 - val_acc: 0.9948
# Epoch 7/20
# 60000/60000 [==============================] - 6s 106us/step - loss: 0.0124 - acc: 0.9961 - val_loss: 0.0178 - val_acc: 0.9948
# Epoch 8/20
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.0107 - acc: 0.9966 - val_loss: 0.0144 - val_acc: 0.9959
# Epoch 9/20
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.0095 - acc: 0.9969 - val_loss: 0.0177 - val_acc: 0.9952
# Epoch 10/20
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.0088 - acc: 0.9971 - val_loss: 0.0153 - val_acc: 0.9956
# Epoch 11/20
# 60000/60000 [==============================] - 7s 108us/step - loss: 0.0076 - acc: 0.9975 - val_loss: 0.0159 - val_acc: 0.9957
# Epoch 12/20
# 60000/60000 [==============================] - 7s 109us/step - loss: 0.0065 - acc: 0.9979 - val_loss: 0.0155 - val_acc: 0.9959
# Epoch 13/20
# 60000/60000 [==============================] - 7s 111us/step - loss: 0.0062 - acc: 0.9980 - val_loss: 0.0180 - val_acc: 0.9953
# Epoch 14/20
# 60000/60000 [==============================] - 7s 109us/step - loss: 0.0055 - acc: 0.9981 - val_loss: 0.0177 - val_acc: 0.9958
# Epoch 15/20
# 60000/60000 [==============================] - 7s 109us/step - loss: 0.0049 - acc: 0.9984 - val_loss: 0.0185 - val_acc: 0.9958
# Epoch 16/20
# 60000/60000 [==============================] - 6s 107us/step - loss: 0.0042 - acc: 0.9986 - val_loss: 0.0210 - val_acc: 0.9954
# Epoch 17/20
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.0044 - acc: 0.9986 - val_loss: 0.0194 - val_acc: 0.9955
# Epoch 18/20
# 60000/60000 [==============================] - 7s 109us/step - loss: 0.0039 - acc: 0.9988 - val_loss: 0.0189 - val_acc: 0.9960
# Epoch 19/20
# 60000/60000 [==============================] - 7s 110us/step - loss: 0.0038 - acc: 0.9988 - val_loss: 0.0191 - val_acc: 0.9959
# Epoch 20/20
# 60000/60000 [==============================] - 7s 112us/step - loss: 0.0034 - acc: 0.9990 - val_loss: 0.0172 - val_acc: 0.9958
# CPU times: user 4min 34s, sys: 34.7 s, total: 5min 8s
# Wall time: 2min 16s

# %%
plot_model(resnet_skip1, to_file='reports/resnet_skip_1.png')

# %%
# %%time
# Resnet with skip 3
resnet_skip3 = create_resnet(layers=3, skips=3)
resnet_skip3.fit(x_train, y_train, batch_size=128, epochs=20, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 22s 374us/step - loss: 0.2355 - acc: 0.9215 - val_loss: 0.0654 - val_acc: 0.9791
# Epoch 2/20
# 60000/60000 [==============================] - 12s 196us/step - loss: 0.0616 - acc: 0.9801 - val_loss: 0.0320 - val_acc: 0.9895
# Epoch 3/20
# 60000/60000 [==============================] - 12s 198us/step - loss: 0.0375 - acc: 0.9883 - val_loss: 0.0241 - val_acc: 0.9922
# Epoch 4/20
# 60000/60000 [==============================] - 11s 183us/step - loss: 0.0283 - acc: 0.9912 - val_loss: 0.0211 - val_acc: 0.9928
# Epoch 5/20
# 60000/60000 [==============================] - 11s 185us/step - loss: 0.0225 - acc: 0.9930 - val_loss: 0.0180 - val_acc: 0.9942
# Epoch 6/20
# 60000/60000 [==============================] - 11s 185us/step - loss: 0.0187 - acc: 0.9943 - val_loss: 0.0168 - val_acc: 0.9946
# Epoch 7/20
# 60000/60000 [==============================] - 11s 183us/step - loss: 0.0171 - acc: 0.9948 - val_loss: 0.0167 - val_acc: 0.9950
# Epoch 8/20
# 60000/60000 [==============================] - 11s 185us/step - loss: 0.0146 - acc: 0.9955 - val_loss: 0.0173 - val_acc: 0.9947
# Epoch 9/20
# 60000/60000 [==============================] - 11s 184us/step - loss: 0.0128 - acc: 0.9959 - val_loss: 0.0161 - val_acc: 0.9950
# Epoch 10/20
# 60000/60000 [==============================] - 11s 185us/step - loss: 0.0112 - acc: 0.9964 - val_loss: 0.0148 - val_acc: 0.9954
# Epoch 11/20
# 60000/60000 [==============================] - 11s 184us/step - loss: 0.0102 - acc: 0.9967 - val_loss: 0.0155 - val_acc: 0.9956
# Epoch 12/20
# 60000/60000 [==============================] - 11s 185us/step - loss: 0.0090 - acc: 0.9971 - val_loss: 0.0159 - val_acc: 0.9955
# Epoch 13/20
# 60000/60000 [==============================] - 11s 185us/step - loss: 0.0079 - acc: 0.9975 - val_loss: 0.0152 - val_acc: 0.9956
# Epoch 14/20
# 60000/60000 [==============================] - 11s 183us/step - loss: 0.0073 - acc: 0.9976 - val_loss: 0.0158 - val_acc: 0.9955
# Epoch 15/20
# 60000/60000 [==============================] - 11s 184us/step - loss: 0.0064 - acc: 0.9979 - val_loss: 0.0155 - val_acc: 0.9957
# Epoch 16/20
# 60000/60000 [==============================] - 11s 187us/step - loss: 0.0064 - acc: 0.9979 - val_loss: 0.0166 - val_acc: 0.9954
# Epoch 17/20
# 60000/60000 [==============================] - 11s 185us/step - loss: 0.0057 - acc: 0.9982 - val_loss: 0.0165 - val_acc: 0.9957
# Epoch 18/20
# 60000/60000 [==============================] - 12s 198us/step - loss: 0.0048 - acc: 0.9984 - val_loss: 0.0171 - val_acc: 0.9959
# Epoch 19/20
# 60000/60000 [==============================] - 12s 193us/step - loss: 0.0046 - acc: 0.9985 - val_loss: 0.0177 - val_acc: 0.9957
# Epoch 20/20
# 60000/60000 [==============================] - 12s 196us/step - loss: 0.0047 - acc: 0.9985 - val_loss: 0.0169 - val_acc: 0.9957
# CPU times: user 8min 32s, sys: 1min 11s, total: 9min 44s
# Wall time: 4min

# %%
plot_model(resnet_skip3, to_file='reports/resnet_skip_3.png')

# %% [markdown]
# ### Now lets create a Functional Model for CIFAR with the same baseline as MNIST.

# %%
# %%time
# Create the CIFAR baseline here.
#inputs = Input(shape=(input_shape,))
inputs = Input(shape=input_shape_cifar)
output = Dense(64, activation='relu')(inputs)
output = Dense(64, activation='relu')(output)
output = Dense(64, activation='relu')(output)
output = Dense(64, activation='relu')(output)
predictions = Dense(10, activation='softmax')(output)
model = Model(inputs=inputs, outputs=predictions)
model.compile(optimizer=SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True),
              loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train_cifar, y_train_cifar, epochs=20, batch_size=64, validation_data=(x_test_cifar, y_test_cifar))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 13s 252us/step - loss: 1.8652 - acc: 0.3213 - val_loss: 1.7420 - val_acc: 0.3654
# Epoch 2/20
# 50000/50000 [==============================] - 6s 123us/step - loss: 1.6760 - acc: 0.3970 - val_loss: 1.7167 - val_acc: 0.3837
# Epoch 3/20
# 50000/50000 [==============================] - 6s 125us/step - loss: 1.6008 - acc: 0.4249 - val_loss: 1.6314 - val_acc: 0.4105
# Epoch 4/20
# 50000/50000 [==============================] - 6s 121us/step - loss: 1.5543 - acc: 0.4436 - val_loss: 1.5396 - val_acc: 0.4518
# Epoch 5/20
# 50000/50000 [==============================] - 6s 123us/step - loss: 1.5166 - acc: 0.4563 - val_loss: 1.5864 - val_acc: 0.4318
# Epoch 6/20
# 50000/50000 [==============================] - 6s 121us/step - loss: 1.4908 - acc: 0.4670 - val_loss: 1.5516 - val_acc: 0.4447
# Epoch 7/20
# 50000/50000 [==============================] - 6s 120us/step - loss: 1.4634 - acc: 0.4760 - val_loss: 1.5016 - val_acc: 0.4627
# Epoch 8/20
# 50000/50000 [==============================] - 6s 119us/step - loss: 1.4413 - acc: 0.4835 - val_loss: 1.5272 - val_acc: 0.4539
# Epoch 9/20
# 50000/50000 [==============================] - 6s 119us/step - loss: 1.4247 - acc: 0.4905 - val_loss: 1.4977 - val_acc: 0.4647
# Epoch 10/20
# 50000/50000 [==============================] - 6s 119us/step - loss: 1.4049 - acc: 0.4995 - val_loss: 1.5645 - val_acc: 0.4537
# Epoch 11/20
# 50000/50000 [==============================] - 6s 120us/step - loss: 1.3915 - acc: 0.5020 - val_loss: 1.4914 - val_acc: 0.4742
# Epoch 12/20
# 50000/50000 [==============================] - 6s 119us/step - loss: 1.3776 - acc: 0.5064 - val_loss: 1.5243 - val_acc: 0.4579
# Epoch 13/20
# 50000/50000 [==============================] - 6s 121us/step - loss: 1.3676 - acc: 0.5123 - val_loss: 1.4549 - val_acc: 0.4822
# Epoch 14/20
# 50000/50000 [==============================] - 6s 120us/step - loss: 1.3547 - acc: 0.5143 - val_loss: 1.4724 - val_acc: 0.4825
# Epoch 15/20
# 50000/50000 [==============================] - 6s 121us/step - loss: 1.3433 - acc: 0.5200 - val_loss: 1.4418 - val_acc: 0.4851
# Epoch 16/20
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.3279 - acc: 0.5249 - val_loss: 1.4473 - val_acc: 0.4891
# Epoch 17/20
# 50000/50000 [==============================] - 6s 125us/step - loss: 1.3225 - acc: 0.5271 - val_loss: 1.4433 - val_acc: 0.4927
# Epoch 18/20
# 50000/50000 [==============================] - 6s 127us/step - loss: 1.3130 - acc: 0.5303 - val_loss: 1.5394 - val_acc: 0.4588
# Epoch 19/20
# 50000/50000 [==============================] - 6s 123us/step - loss: 1.2996 - acc: 0.5340 - val_loss: 1.4800 - val_acc: 0.4705
# Epoch 20/20
# 50000/50000 [==============================] - 6s 126us/step - loss: 1.2927 - acc: 0.5369 - val_loss: 1.4914 - val_acc: 0.4761
# CPU times: user 3min 11s, sys: 16.7 s, total: 3min 27s
# Wall time: 2min 8s

# %% [markdown]
# ### Now lets create a ResNet for CIFAR with the same layers and compare it with MNIST.
# Why does our accuracy change so much?

# %%
# %%time
# Create the CIFAR ResNet here.
resnet_cifar = create_resnet(input_shape=input_shape_cifar)
resnet_cifar.fit(x_train_cifar, y_train_cifar, epochs=20, batch_size=64, validation_data=(x_test_cifar, y_test_cifar))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 24s 486us/step - loss: 0.3188 - acc: 0.8989 - val_loss: 0.2929 - val_acc: 0.8995
# Epoch 2/20
# 50000/50000 [==============================] - 16s 318us/step - loss: 0.2952 - acc: 0.8997 - val_loss: 0.2778 - val_acc: 0.9004
# Epoch 3/20
# 50000/50000 [==============================] - 16s 321us/step - loss: 0.2862 - acc: 0.9001 - val_loss: 0.2936 - val_acc: 0.9012
# Epoch 4/20
# 50000/50000 [==============================] - 16s 323us/step - loss: 0.2792 - acc: 0.9007 - val_loss: 0.2665 - val_acc: 0.9040
# Epoch 5/20
# 50000/50000 [==============================] - 16s 327us/step - loss: 0.2733 - acc: 0.9016 - val_loss: 0.2576 - val_acc: 0.9044
# Epoch 6/20
# 50000/50000 [==============================] - 16s 328us/step - loss: 0.2686 - acc: 0.9024 - val_loss: 0.2518 - val_acc: 0.9061
# Epoch 7/20
# 50000/50000 [==============================] - 17s 331us/step - loss: 0.2631 - acc: 0.9037 - val_loss: 0.2467 - val_acc: 0.9075
# Epoch 8/20
# 50000/50000 [==============================] - 17s 330us/step - loss: 0.2584 - acc: 0.9049 - val_loss: 0.2530 - val_acc: 0.9060
# Epoch 9/20
# 50000/50000 [==============================] - 17s 332us/step - loss: 0.2546 - acc: 0.9057 - val_loss: 0.2480 - val_acc: 0.9065
# Epoch 10/20
# 50000/50000 [==============================] - 17s 331us/step - loss: 0.2507 - acc: 0.9069 - val_loss: 0.2431 - val_acc: 0.9081
# Epoch 11/20
# 50000/50000 [==============================] - 17s 332us/step - loss: 0.2477 - acc: 0.9075 - val_loss: 0.2325 - val_acc: 0.9122
# Epoch 12/20
# 50000/50000 [==============================] - 17s 333us/step - loss: 0.2440 - acc: 0.9087 - val_loss: 0.2301 - val_acc: 0.9128
# Epoch 13/20
# 50000/50000 [==============================] - 17s 333us/step - loss: 0.2420 - acc: 0.9093 - val_loss: 0.2319 - val_acc: 0.9120
# Epoch 14/20
# 50000/50000 [==============================] - 17s 332us/step - loss: 0.2391 - acc: 0.9102 - val_loss: 0.2326 - val_acc: 0.9113
# Epoch 15/20
# 50000/50000 [==============================] - 17s 332us/step - loss: 0.2372 - acc: 0.9108 - val_loss: 0.2315 - val_acc: 0.9131
# Epoch 16/20
# 50000/50000 [==============================] - 17s 335us/step - loss: 0.2359 - acc: 0.9114 - val_loss: 0.2295 - val_acc: 0.9128
# Epoch 17/20
# 50000/50000 [==============================] - 17s 332us/step - loss: 0.2325 - acc: 0.9125 - val_loss: 0.2276 - val_acc: 0.9138
# Epoch 18/20
# 50000/50000 [==============================] - 17s 332us/step - loss: 0.2312 - acc: 0.9131 - val_loss: 0.2294 - val_acc: 0.9127
# Epoch 19/20
# 50000/50000 [==============================] - 17s 333us/step - loss: 0.2296 - acc: 0.9136 - val_loss: 0.2288 - val_acc: 0.9128
# Epoch 20/20
# 50000/50000 [==============================] - 17s 332us/step - loss: 0.2276 - acc: 0.9145 - val_loss: 0.2301 - val_acc: 0.9127
# CPU times: user 11min 25s, sys: 1min 42s, total: 13min 8s
# Wall time: 5min 40s

# %% [markdown]
# ### Now lets create a custom ResNet.
# Change the layer widths, dropout layers, batch sizes, and skip connections to see what we could do to make the ResNet better. Use the knowledge you gained from Lab 3 to do this.

# %%
# Create your own ResNet here.
custom_model = create_resnet(layers=3, skips=2, input_shape=input_shape_cifar, neuron=256, lr=1e-3, dropout=0.1)
best_save = ModelCheckpoint('models/best_cifar.hdf5', save_best_only=True, monitor='val_acc', mode='max')
history = custom_model.fit(x_train_cifar, y_train_cifar, epochs=20, batch_size=64, validation_data=(x_test_cifar, y_test_cifar), callbacks=[best_save])
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 23s 452us/step - loss: 0.2725 - acc: 0.9021 - val_loss: 0.2521 - val_acc: 0.9072
# Epoch 2/20
# 50000/50000 [==============================] - 19s 371us/step - loss: 0.2485 - acc: 0.9071 - val_loss: 0.2770 - val_acc: 0.9028
# Epoch 3/20
# 50000/50000 [==============================] - 19s 375us/step - loss: 0.2385 - acc: 0.9099 - val_loss: 0.2569 - val_acc: 0.9061
# Epoch 4/20
# 50000/50000 [==============================] - 19s 381us/step - loss: 0.2320 - acc: 0.9119 - val_loss: 0.2413 - val_acc: 0.9090
# Epoch 5/20
# 50000/50000 [==============================] - 19s 382us/step - loss: 0.2266 - acc: 0.9137 - val_loss: 0.2447 - val_acc: 0.9092
# Epoch 6/20
# 50000/50000 [==============================] - 19s 388us/step - loss: 0.2220 - acc: 0.9151 - val_loss: 0.2386 - val_acc: 0.9099
# Epoch 7/20
# 50000/50000 [==============================] - 19s 388us/step - loss: 0.2180 - acc: 0.9163 - val_loss: 0.2339 - val_acc: 0.9114
# Epoch 8/20
# 50000/50000 [==============================] - 19s 385us/step - loss: 0.2146 - acc: 0.9175 - val_loss: 0.2275 - val_acc: 0.9115
# Epoch 9/20
# 50000/50000 [==============================] - 19s 386us/step - loss: 0.2117 - acc: 0.9190 - val_loss: 0.2323 - val_acc: 0.9117
# Epoch 10/20
# 50000/50000 [==============================] - 19s 388us/step - loss: 0.2080 - acc: 0.9200 - val_loss: 0.2285 - val_acc: 0.9134
# Epoch 11/20
# 50000/50000 [==============================] - 19s 387us/step - loss: 0.2058 - acc: 0.9205 - val_loss: 0.2246 - val_acc: 0.9140
# Epoch 12/20
# 50000/50000 [==============================] - 19s 387us/step - loss: 0.2032 - acc: 0.9214 - val_loss: 0.2303 - val_acc: 0.9126
# Epoch 13/20
# 50000/50000 [==============================] - 20s 393us/step - loss: 0.2007 - acc: 0.9226 - val_loss: 0.2191 - val_acc: 0.9164
# Epoch 14/20
# 50000/50000 [==============================] - 19s 388us/step - loss: 0.1982 - acc: 0.9233 - val_loss: 0.2302 - val_acc: 0.9123
# Epoch 15/20
# 50000/50000 [==============================] - 20s 392us/step - loss: 0.1955 - acc: 0.9239 - val_loss: 0.2178 - val_acc: 0.9166
# Epoch 16/20
# 50000/50000 [==============================] - 20s 393us/step - loss: 0.1936 - acc: 0.9250 - val_loss: 0.2185 - val_acc: 0.9161
# Epoch 17/20
# 50000/50000 [==============================] - 19s 389us/step - loss: 0.1910 - acc: 0.9259 - val_loss: 0.2302 - val_acc: 0.9132
# Epoch 18/20
# 50000/50000 [==============================] - 19s 387us/step - loss: 0.1889 - acc: 0.9268 - val_loss: 0.2429 - val_acc: 0.9108
# Epoch 19/20
# 50000/50000 [==============================] - 20s 394us/step - loss: 0.1869 - acc: 0.9278 - val_loss: 0.2183 - val_acc: 0.9163
# Epoch 20/20
# 50000/50000 [==============================] - 19s 388us/step - loss: 0.1855 - acc: 0.9281 - val_loss: 0.2295 - val_acc: 0.9135
