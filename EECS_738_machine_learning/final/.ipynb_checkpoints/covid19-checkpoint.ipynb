# %%
import pandas as pd
import numpy as np
from sklearn.metrics import make_scorer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Flatten, BatchNormalization, Dropout
from tensorflow.keras.models import Model, Sequential, model_from_json
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from itertools import product

import matplotlib.pyplot as plt
import seaborn as sns
import os, sys, math

# %%
#df = pd.read_csv('data/04-02-2020.csv')
df = pd.read_csv('data/covid_19_clean_complete.csv')
df.rename(columns={'Date':'Last_Update', 'Long': 'Long_'}, inplace=True)
df['Last_Update'] = pd.to_datetime(df['Last_Update'])
df.fillna('missing', inplace=True)
df
# Out:
#       Province/State         Country/Region        Lat      Long_ Last_Update  \
# 0            missing            Afghanistan  33.000000  65.000000  2020-01-22
# 1            missing                Albania  41.153300  20.168300  2020-01-22
# 2            missing                Algeria  28.033900   1.659600  2020-01-22
# 3            missing                Andorra  42.506300   1.521800  2020-01-22
# 4            missing                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 29563        missing         Western Sahara  24.215500 -12.885800  2020-05-12
# 29564        missing  Sao Tome and Principe   0.186360   6.613081  2020-05-12
# 29565        missing                  Yemen  15.552727  48.516388  2020-05-12
# 29566        missing                Comoros -11.645500  43.333300  2020-05-12
# 29567        missing             Tajikistan  38.861034  71.276093  2020-05-12
#
#        Confirmed  Deaths  Recovered
# 0              0       0          0
# 1              0       0          0
# 2              0       0          0
# 3              0       0          0
# 4              0       0          0
# ...          ...     ...        ...
# 29563          6       0          6
# 29564        208       5          4
# 29565         65      10          1
# 29566         11       1          0
# 29567        729      21          0
#
# [29568 rows x 8 columns]

# %%
row=df.iloc[0]
row
# Out:
# Province/State                missing
# Country/Region            Afghanistan
# Lat                                33
# Long_                              65
# Last_Update       2020-01-22 00:00:00
# Confirmed                           0
# Deaths                              0
# Recovered                           0
# Name: 0, dtype: object

# %%
df_partial = df[(df['Province/State'] == row['Province/State']) & (df['Country/Region'] == row['Country/Region']) & (df['Last_Update'] > row['Last_Update'])]
df_partial_desc = df_partial.sort_values(['Last_Update'], ascending=True)
df_partial_desc.iloc[0]
# Out:
# Province/State                missing
# Country/Region            Afghanistan
# Lat                                33
# Long_                              65
# Last_Update       2020-01-23 00:00:00
# Confirmed                           0
# Deaths                              0
# Recovered                           0
# Name: 264, dtype: object

# %%
#past1 = []
def fill_past1(idx, row):
    df_partial = df[(df['Province/State'] == row['Province/State']) & (df['Country/Region'] == row['Country/Region']) & (df['Last_Update'] > row['Last_Update'])]
    df_partial_desc = df_partial.sort_values(['Last_Update'], ascending=True)
    if len(df_partial_desc.index) > 0:
        confirmed_fill = df_partial_desc.iloc[0]['Confirmed']
        death_fill = df_partial_desc.iloc[0]['Deaths']
        recovered_fill = df_partial_desc.iloc[0]['Recovered']
        df_past.set_value(idx, 'Confirmed_past1', confirmed_fill)
        df_past.set_value(idx, 'Deaths_past1', death_fill)
        df_past.set_value(idx, 'Recovered_past1', recovered_fill)


df_past = df.copy()
df_past['Confirmed_past1'] = pd.Series(float('nan'))
df_past['Deaths_past1'] = pd.Series(float('nan'))
df_past['Recovered_past1'] = pd.Series(float('nan'))
for idx, row in df_past.iterrows():
    fill_past1(idx, row)

print(df_past)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-381-76cdeb6e734c> in <module>
#      10 df_past['Confirmed_past1'] = pd.Series(float('nan'))
#      11 for idx, row in df_past.iterrows():
# ---> 12     fill_past1(idx, row)
#      13
#      14 print(df_past['Confirmed_past1'])
#
# <ipython-input-381-76cdeb6e734c> in fill_past1(idx, row)
#       1 #past1 = []
#       2 def fill_past1(idx, row):
# ----> 3     df_partial = df[(df['Province/State'] == row['Province/State']) & (df['Country/Region'] == row['Country/Region']) & (df['Last_Update'] > row['Last_Update'])]
#       4     df_partial_desc = df_partial.sort_values(['Last_Update'], ascending=True)
#       5     if len(df_partial_desc.index) > 0:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984         # Do we have a (boolean) 1d indexer?
#    2985         if com.is_bool_indexer(key):
# -> 2986             return self._getitem_bool_array(key)
#    2987
#    2988         # We are left with two options: a single key, and a collection of keys,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3038         key = check_bool_indexer(self.index, key)
#    3039         indexer = key.nonzero()[0]
# -> 3040         return self.take(indexer, axis=0)
#    3041
#    3042     def _getitem_multilevel(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3601         self._consolidate_inplace()
#    3602
# -> 3603         new_data = self._data.take(
#    3604             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3605         )
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1387         n = self.shape[axis]
#    1388         if convert:
# -> 1389             indexer = maybe_convert_indices(indexer, n)
#    1390
#    1391         if verify:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexers.py in maybe_convert_indices(indices, n)
#     192             return np.empty(0, dtype=np.intp)
#     193
# --> 194     mask = indices < 0
#     195     if mask.any():
#     196         indices = indices.copy()
#
# KeyboardInterrupt:

# %%
#d = {'Lat':'Lat_avg', 'Long_':'Long_avg','Confirmed':'Confirmed_sum', 'Deaths':'Deaths_sum', 'Recovered':'Recovered_sum'}
#df_group = df.groupby(['Last_Update', 'Province_State']).agg({'Lat':'mean', 'Long_':'mean','Confirmed':'sum', 'Deaths':'sum', 'Recovered':'sum'}).rename(columns=d)
#df_group.reset_index(inplace=True)
start_time = df['Last_Update'].min()
df_train = df.copy()
#df_train['hour_diff'] = (df['Last_Update'] - start_time) / np.timedelta64(1, 'd')
df_train['day_diff'] = (df['Last_Update'] - start_time).dt.days

# df_train['year'] = df_train['Last_Update'].dt.year
# df_train['month'] = df_train['Last_Update'].dt.month
# df_train['day'] = df_train['Last_Update'].dt.day

# DAY_SHIFT = 3
# shift_column_names = []
# for i in range(1, DAY_SHIFT + 1):
#     confirm_col, deaths_col, recovered_col = 'Confirmed_past{}'.format(i), 'Deaths_past{}'.format(i), 'Recovered_past{}'.format(i)
#     df_train[confirm_col] = df['Confirmed'].shift(i)
#     df_train[deaths_col] = df['Deaths'].shift(i)
#     df_train[recovered_col] = df['Recovered'].shift(i)
#     shift_column_names.extend([confirm_col, deaths_col, recovered_col])
# df_train.dropna(subset=shift_column_names, inplace=True, axis=0, how='any')

df_train.drop(columns=['Country/Region', 'Province/State', 'Last_Update', 'Deaths', 'Recovered'], inplace=True)
df_train
# Out:
#              Lat      Long_  Confirmed  day_diff
# 0      33.000000  65.000000          0         0
# 1      41.153300  20.168300          0         0
# 2      28.033900   1.659600          0         0
# 3      42.506300   1.521800          0         0
# 4     -11.202700  17.873900          0         0
# ...          ...        ...        ...       ...
# 29563  24.215500 -12.885800          6       111
# 29564   0.186360   6.613081        208       111
# 29565  15.552727  48.516388         65       111
# 29566 -11.645500  43.333300         11       111
# 29567  38.861034  71.276093        729       111
#
# [29568 rows x 4 columns]

# %%
# df_train.dropna(subset=['Lat', 'Long_'], inplace=True)
# df_train
# Out:
#             Lat       Long_  Confirmed  hour_diff  Confirmed_past1  \
# 2     37.767072  -75.632346         10      948.1             61.0
# 3     43.452658 -116.241552        312      948.1             10.0
# 4     41.330756  -94.471059          1      948.1            312.0
# 5     40.190586  -92.600782          6      948.1              1.0
# 6     35.884942  -94.658593          9      948.1              6.0
# ...         ...         ...        ...        ...              ...
# 2563   6.423800  -66.589700        146      948.1            205.0
# 2564  14.058324  108.277199        233      948.1            146.0
# 2565  31.952200   35.233200        161      948.1            233.0
# 2566 -13.133897   27.849332         39      948.1            161.0
# 2567 -19.015438   29.154857          9      948.1             39.0
#
#       Deaths_past1  Recovered_past1  Confirmed_past2  Deaths_past2  \
# 2              1.0              0.0              6.0           0.0
# 3              0.0              0.0             61.0           1.0
# 4              3.0              0.0             10.0           0.0
# 5              0.0              0.0            312.0           3.0
# 6              0.0              0.0              1.0           0.0
# ...            ...              ...              ...           ...
# 2563           2.0             25.0            350.0           4.0
# 2564           5.0             43.0            205.0           2.0
# 2565           0.0             75.0            146.0           5.0
# 2566           1.0             18.0            233.0           0.0
# 2567           1.0              0.0            161.0           1.0
#
#       Recovered_past2
# 2                 0.0
# 3                 0.0
# 4                 0.0
# 5                 0.0
# 6                 0.0
# ...               ...
# 2563             62.0
# 2564             25.0
# 2565             43.0
# 2566             75.0
# 2567             18.0
#
# [2513 rows x 10 columns]

# %%
y_label = 'Confirmed'
df_y = df_train[y_label]
df_train.drop(columns=[y_label], inplace=True)
df_train
# Out:
#              Lat      Long_  day_diff  Confirmed_past1  Deaths_past1  \
# 3      42.506300   1.521800         0              0.0           0.0
# 4     -11.202700  17.873900         0              0.0           0.0
# 5      17.060800 -61.796400         0              0.0           0.0
# 6     -38.416100 -63.616700         0              0.0           0.0
# 7      40.069100  45.038200         0              0.0           0.0
# ...          ...        ...       ...              ...           ...
# 29563  24.215500 -12.885800       111            194.0           0.0
# 29564   0.186360   6.613081       111              6.0           0.0
# 29565  15.552727  48.516388       111            208.0           5.0
# 29566 -11.645500  43.333300       111             65.0          10.0
# 29567  38.861034  71.276093       111             11.0           1.0
#
#        Recovered_past1  Confirmed_past2  Deaths_past2  Recovered_past2  \
# 3                  0.0              0.0           0.0              0.0
# 4                  0.0              0.0           0.0              0.0
# 5                  0.0              0.0           0.0              0.0
# 6                  0.0              0.0           0.0              0.0
# 7                  0.0              0.0           0.0              0.0
# ...                ...              ...           ...              ...
# 29563              2.0              1.0           0.0              1.0
# 29564              6.0            194.0           0.0              2.0
# 29565              4.0              6.0           0.0              6.0
# 29566              1.0            208.0           5.0              4.0
# 29567              0.0             65.0          10.0              1.0
#
#        Confirmed_past3  Deaths_past3  Recovered_past3
# 3                  0.0           0.0              0.0
# 4                  0.0           0.0              0.0
# 5                  0.0           0.0              0.0
# 6                  0.0           0.0              0.0
# 7                  0.0           0.0              0.0
# ...                ...           ...              ...
# 29563             13.0           0.0             13.0
# 29564              1.0           0.0              1.0
# 29565            194.0           0.0              2.0
# 29566              6.0           0.0              6.0
# 29567            208.0           5.0              4.0
#
# [29565 rows x 12 columns]

# %%
# # union all datasets
# input_folder = 'data'
# df = pd.read_csv('data/02-27-2020.csv')
# columns = df.columns
# for file_name in os.listdir(input_folder)[1:]:
#     _df = pd.read_csv('data/{}'.format(file_name))
#     _df = _df.rename({
#         'Province_State': 'Province/State',
#         'Country_Region': 'Country/Region',
#         'Last_Update': 'Last Update'}, axis=1)[columns.tolist()]
#     _df['Last Update'] = pd.to_datetime(_df['Last Update'])
#     df = pd.concat([df, _df])
# df['Last Update'] = pd.to_datetime(df['Last Update'])
# df.fillna('missing', inplace=True)
# df['Country/Region'].replace(['Mainland China'], 'China', inplace=True)
# df['Country/Region'].replace(['United Kingdom'], 'UK', inplace=True)
# df['year'] = df['Last Update'].dt.year
# df['month'] = df['Last Update'].dt.month
# df['day'] = df['Last Update'].dt.day
# ctg_cols = ['Country/Region', 'Province/State']
# df_dummy = pd.get_dummies(df, columns=ctg_cols)
# y_label = 'Confirmed'
# df_y = df_dummy[y_label]
# df_dummy.drop(columns=['Last Update', 'Deaths', 'Recovered', y_label], inplace=True)

# %%
num_pipeline = Pipeline([('standard_scaler', StandardScaler())])
df_train_normed = df_train.copy()
df_train_normed[df_train_normed.columns] = num_pipeline.fit_transform(df_train[df_train.columns])
x_train, x_test, y_train, y_test = train_test_split(df_train_normed, df_y, test_size=0.2, random_state=1)
df_train_normed
# Out:
#             Lat     Long_  day_diff  Confirmed_past1  Deaths_past1  \
# 3      0.853715 -0.303192 -1.716998        -0.108461     -0.103838
# 4     -1.315950 -0.070850 -1.716998        -0.108461     -0.103838
# 5     -0.174198 -1.202859 -1.716998        -0.108461     -0.103838
# 6     -2.415281 -1.228723 -1.716998        -0.108461     -0.103838
# 7      0.755260  0.315118 -1.716998        -0.108461     -0.103838
# ...         ...       ...       ...              ...           ...
# 29563  0.114828 -0.507904  1.716650        -0.103246     -0.103838
# 29564 -0.855870 -0.230851  1.716650        -0.108300     -0.103838
# 29565 -0.235120  0.364539  1.716650        -0.102870     -0.101900
# 29566 -1.333837  0.290894  1.716650        -0.106714     -0.099963
# 29567  0.706459  0.687924  1.716650        -0.108166     -0.103450
#
#        Recovered_past1  Confirmed_past2  Deaths_past2  Recovered_past2  \
# 3            -0.132479        -0.108461     -0.103838        -0.132479
# 4            -0.132479        -0.108461     -0.103838        -0.132479
# 5            -0.132479        -0.108461     -0.103838        -0.132479
# 6            -0.132479        -0.108461     -0.103838        -0.132479
# 7            -0.132479        -0.108461     -0.103838        -0.132479
# ...                ...              ...           ...              ...
# 29563        -0.132248        -0.108434     -0.103838        -0.132364
# 29564        -0.131787        -0.103246     -0.103838        -0.132248
# 29565        -0.132018        -0.108300     -0.103838        -0.131787
# 29566        -0.132364        -0.102869     -0.101900        -0.132018
# 29567        -0.132479        -0.106714     -0.099963        -0.132364
#
#        Confirmed_past3  Deaths_past3  Recovered_past3
        keras.layers.Dropout(0.2)
    ]

    for i in range(2):
        model_sequences.append(keras.layers.Dense(units=neuron, kernel_initializer=init,
                                                  #activation='relu',
                                                  #kernel_regularizer=regularizers.l1_l2(l1=0.05, l2=0.05),
                                                  input_shape=x_train.shape[1:]))
        model_sequences.append(keras.layers.BatchNormalization())
        model_sequences.append(keras.layers.LeakyReLU(alpha=act_alpha))
        model_sequences.append(keras.layers.Dropout(0.2))

    model_sequences.append(Dense(units=1, name='score_output',
                                 #activation='relu'
                                ))
    model_sequences.append(keras.layers.LeakyReLU(alpha=act_alpha))

    nn_model = keras.models.Sequential(model_sequences)
    nn_model.compile(optimizer=optimizer, loss='mae', metrics=[coeff_determination])
    return nn_model

# lr_schedule = keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=1e-2,
#     decay_steps=1000,
#     decay_rate=0.9)
optimizer = keras.optimizers.Adamax(lr=0.1)
nn_model = create_keras_model(optimizer=optimizer, neuron=700, init='he_normal', act_alpha=0.05)
print("Keras model constructed")
#early_stopping_cb = EarlyStopping(patience=20)
history = nn_model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=200, callbacks=[], verbose=1)

fig, ax1 = plt.subplots()
ax1.set_xlabel('epochs')
df_history = pd.DataFrame(history.history)
#ax1.set_ylabel('exp', color=color)
ax1.plot(df_history.index, df_history['loss'], color='green', label="loss")
ax1.plot(df_history.index, df_history['val_loss'], color='blue', label="val_loss")
ax1.tick_params(axis='y')
ax1.legend(loc="upper right")
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

ax2.plot(df_history.index, df_history['coeff_determination'], color='red', label="r2")
ax2.plot(df_history.index, df_history['val_coeff_determination'], color='orange', label="val_r2")
ax2.tick_params(axis='y')
ax2.set_ylim([0, 1])
ax2.legend(loc="center right")

#fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# Keras model constructed
# Train on 23652 samples, validate on 5913 samples
# Epoch 1/200
# 23652/23652 [==============================] - 11s 473us/step - loss: 3977.9836 - coeff_determination: -0.0433 - val_loss: 3830.0022 - val_coeff_determination: -0.0274
# Epoch 2/200
# 23652/23652 [==============================] - 9s 376us/step - loss: 3948.5482 - coeff_determination: -0.2164 - val_loss: 3773.6360 - val_coeff_determination: 0.0660
# Epoch 3/200
# 23652/23652 [==============================] - 9s 392us/step - loss: 3905.2637 - coeff_determination: -0.2009 - val_loss: 3684.0441 - val_coeff_determination: 0.0593
# Epoch 4/200
# 23652/23652 [==============================] - 9s 390us/step - loss: 3884.8996 - coeff_determination: -0.4323 - val_loss: 3702.6098 - val_coeff_determination: -0.9532
# Epoch 5/200
# 23652/23652 [==============================] - 9s 391us/step - loss: 3856.7106 - coeff_determination: -0.2275 - val_loss: 3911.7015 - val_coeff_determination: -4.7641
# Epoch 6/200
# 23652/23652 [==============================] - 9s 391us/step - loss: 3840.2074 - coeff_determination: -0.0521 - val_loss: 3581.7496 - val_coeff_determination: -0.1236
# Epoch 7/200
# 23652/23652 [==============================] - 9s 392us/step - loss: 3811.0803 - coeff_determination: -0.2052 - val_loss: 3463.0614 - val_coeff_determination: 0.0940
# Epoch 8/200
# 23652/23652 [==============================] - 9s 384us/step - loss: 3757.3388 - coeff_determination: -0.9170 - val_loss: 3339.0677 - val_coeff_determination: 0.1310
# 23652/23652 [==============================] - 9s 378us/step - loss: 2852.5988 - coeff_determination: -0.6317 - val_loss: 3306.1806 - val_coeff_determination: -12.5091
# Epoch 27/200
# 23652/23652 [==============================] - 9s 380us/step - loss: 2853.0404 - coeff_determination: -5.2354 - val_loss: 3392.2861 - val_coeff_determination: -0.8338
# Epoch 28/200
# 23652/23652 [==============================] - 9s 396us/step - loss: 2797.5311 - coeff_determination: -0.8278 - val_loss: 3577.3943 - val_coeff_determination: -0.1877
# Epoch 29/200
# 23652/23652 [==============================] - 9s 401us/step - loss: 2830.0444 - coeff_determination: -0.2569 - val_loss: 3266.1370 - val_coeff_determination: -0.4713
# Epoch 30/200
# 23652/23652 [==============================] - 9s 400us/step - loss: 2799.6419 - coeff_determination: -0.4869 - val_loss: 2742.0222 - val_coeff_determination: -0.6485
# Epoch 31/200
# 23652/23652 [==============================] - 9s 397us/step - loss: 2789.6779 - coeff_determination: -0.1416 - val_loss: 3048.3835 - val_coeff_determination: -1.2511
# Epoch 32/200
# 23652/23652 [==============================] - 9s 401us/step - loss: 2754.2818 - coeff_determination: -0.5772 - val_loss: 3235.0423 - val_coeff_determination: -0.9511
# Epoch 33/200
# 23652/23652 [==============================] - 9s 396us/step - loss: 2717.3737 - coeff_determination: -0.6088 - val_loss: 2782.7023 - val_coeff_determination: -0.8263
# Epoch 34/200
# 23652/23652 [==============================] - 9s 393us/step - loss: 2738.8951 - coeff_determination: -0.6678 - val_loss: 2647.1965 - val_coeff_determination: -0.3858
# Epoch 35/200
# 23652/23652 [==============================] - 9s 399us/step - loss: 2740.9646 - coeff_determination: -0.5133 - val_loss: 3263.7824 - val_coeff_determination: -1.4205
# Epoch 36/200
# 23652/23652 [==============================] - 9s 396us/step - loss: 2743.7205 - coeff_determination: -0.2698 - val_loss: 3312.4376 - val_coeff_determination: -5.9689
# Epoch 37/200
# 23652/23652 [==============================] - 9s 379us/step - loss: 2735.3649 - coeff_determination: -204.7437 - val_loss: 3022.5888 - val_coeff_determination: -2.6556
# Epoch 38/200
# 23652/23652 [==============================] - 9s 387us/step - loss: 2674.8782 - coeff_determination: -0.1391 - val_loss: 2721.8975 - val_coeff_determination: -0.7802
# Epoch 39/200
# 23652/23652 [==============================] - 9s 381us/step - loss: 2738.1263 - coeff_determination: -0.1587 - val_loss: 2778.1556 - val_coeff_determination: -0.9196
# Epoch 40/200
# 23652/23652 [==============================] - 9s 381us/step - loss: 2723.7988 - coeff_determination: -0.0749 - val_loss: 2581.3904 - val_coeff_determination: -0.1998
# Epoch 41/200
# 23652/23652 [==============================] - 9s 398us/step - loss: 2661.6366 - coeff_determination: -2.4100 - val_loss: 2635.9234 - val_coeff_determination: -0.4411
# Epoch 42/200
# 23652/23652 [==============================] - 10s 415us/step - loss: 2680.1161 - coeff_determination: -0.1852 - val_loss: 2874.0380 - val_coeff_determination: -0.9167
# Epoch 43/200
# 23652/23652 [==============================] - 10s 403us/step - loss: 2715.9820 - coeff_determination: -1.1466 - val_loss: 2875.4349 - val_coeff_determination: -0.9818
# Epoch 44/200
# 23652/23652 [==============================] - 9s 387us/step - loss: 2688.9683 - coeff_determination: -0.7760 - val_loss: 3083.9062 - val_coeff_determination: -1.1014
# Epoch 63/200
# 23652/23652 [==============================] - 9s 381us/step - loss: 2618.2095 - coeff_determination: -0.5634 - val_loss: 3360.4508 - val_coeff_determination: -3.9544
# Epoch 64/200
# 23652/23652 [==============================] - 9s 389us/step - loss: 2594.7618 - coeff_determination: -0.6472 - val_loss: 3452.1915 - val_coeff_determination: -11.8553
# Epoch 65/200
# 23652/23652 [==============================] - 9s 388us/step - loss: 2644.7245 - coeff_determination: -1.4576 - val_loss: 3475.7936 - val_coeff_determination: -11.3109
# Epoch 66/200
# 23652/23652 [==============================] - 9s 381us/step - loss: 2587.2350 - coeff_determination: -7.1080 - val_loss: 3537.6760 - val_coeff_determination: -3.2387
# Epoch 67/200
# 23652/23652 [==============================] - 9s 373us/step - loss: 2616.5367 - coeff_determination: -0.2078 - val_loss: 3110.5203 - val_coeff_determination: -3.4193
# Epoch 68/200
# 23652/23652 [==============================] - 9s 369us/step - loss: 2582.0553 - coeff_determination: -0.4676 - val_loss: 2873.6327 - val_coeff_determination: -0.8394
# Epoch 69/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2649.7647 - coeff_determination: -0.3981 - val_loss: 2910.2148 - val_coeff_determination: -2.2617
# Epoch 70/200
# 23652/23652 [==============================] - 9s 364us/step - loss: 2576.3916 - coeff_determination: -0.1695 - val_loss: 3111.2834 - val_coeff_determination: -4.4986
# Epoch 71/200
# 23652/23652 [==============================] - 9s 367us/step - loss: 2551.4067 - coeff_determination: -1182.9190 - val_loss: 2984.8424 - val_coeff_determination: -3.3626
# Epoch 72/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2582.3764 - coeff_determination: -0.3060 - val_loss: 3034.6439 - val_coeff_determination: -1.5757
# Epoch 73/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2537.3118 - coeff_determination: -0.2593 - val_loss: 2569.0240 - val_coeff_determination: -0.7831
# Epoch 74/200
# 23652/23652 [==============================] - 9s 370us/step - loss: 2642.2702 - coeff_determination: -0.1391 - val_loss: 2686.9721 - val_coeff_determination: -0.3057
# Epoch 75/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2612.6880 - coeff_determination: -1458.5968 - val_loss: 3604.2166 - val_coeff_determination: -8.3483
# Epoch 76/200
# 23652/23652 [==============================] - 9s 367us/step - loss: 2558.0142 - coeff_determination: -0.1275 - val_loss: 2945.3766 - val_coeff_determination: -2.4218
# Epoch 77/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2574.5672 - coeff_determination: -0.5565 - val_loss: 3106.6088 - val_coeff_determination: -2.3656
# Epoch 78/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2580.2274 - coeff_determination: -0.4509 - val_loss: 2953.7169 - val_coeff_determination: -2.6824
# Epoch 79/200
# 23652/23652 [==============================] - 9s 373us/step - loss: 2550.8044 - coeff_determination: -0.1010 - val_loss: 2788.4716 - val_coeff_determination: -2.4707
# Epoch 80/200
# 23652/23652 [==============================] - 9s 369us/step - loss: 2584.4614 - coeff_determination: -0.3963 - val_loss: 2860.5887 - val_coeff_determination: -1.6805
# Epoch 81/200
# 23652/23652 [==============================] - 9s 368us/step - loss: 2585.2231 - coeff_determination: -0.5802 - val_loss: 3457.7876 - val_coeff_determination: -6.1723
# Epoch 82/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2544.4424 - coeff_determination: -0.0190 - val_loss: 3013.6502 - val_coeff_determination: -4.0419
# Epoch 83/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2544.7467 - coeff_determination: -0.2359 - val_loss: 3161.7632 - val_coeff_determination: -2.0167
# Epoch 84/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2597.1158 - coeff_determination: -0.1062 - val_loss: 3175.1238 - val_coeff_determination: -2.9451
# Epoch 85/200
# 23652/23652 [==============================] - 9s 364us/step - loss: 2554.7564 - coeff_determination: -0.4848 - val_loss: 3170.0264 - val_coeff_determination: -8.2139
# Epoch 86/200
# 23652/23652 [==============================] - 9s 375us/step - loss: 2555.1171 - coeff_determination: -0.3943 - val_loss: 3006.6136 - val_coeff_determination: -0.7963
# Epoch 87/200
# 23652/23652 [==============================] - 9s 383us/step - loss: 2609.7332 - coeff_determination: -2.4117 - val_loss: 3147.2307 - val_coeff_determination: -2.9972
# Epoch 88/200
# 23652/23652 [==============================] - 9s 381us/step - loss: 2550.4362 - coeff_determination: -0.0916 - val_loss: 3012.0847 - val_coeff_determination: -7.6271
# Epoch 89/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2553.5460 - coeff_determination: 0.0672 - val_loss: 2831.4328 - val_coeff_determination: -3.8448
# Epoch 90/200
# 23652/23652 [==============================] - 9s 367us/step - loss: 2539.2423 - coeff_determination: 0.0937 - val_loss: 3228.2241 - val_coeff_determination: -7.4014
# Epoch 91/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2591.9310 - coeff_determination: -0.6146 - val_loss: 2874.1021 - val_coeff_determination: -2.3057
# Epoch 92/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2512.5049 - coeff_determination: -0.3761 - val_loss: 2822.0676 - val_coeff_determination: -3.3036
# Epoch 93/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2516.7194 - coeff_determination: -408.3391 - val_loss: 3044.3701 - val_coeff_determination: -2.4270
# Epoch 94/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2613.5375 - coeff_determination: -0.6372 - val_loss: 3059.2066 - val_coeff_determination: -4.4387
# Epoch 95/200
# 23652/23652 [==============================] - 9s 364us/step - loss: 2547.6248 - coeff_determination: -0.1692 - val_loss: 2987.5281 - val_coeff_determination: -2.4584
# Epoch 96/200
# 23652/23652 [==============================] - 9s 377us/step - loss: 2496.9721 - coeff_determination: -0.5354 - val_loss: 3074.5244 - val_coeff_determination: -3.2894
# Epoch 97/200
# 23652/23652 [==============================] - 9s 375us/step - loss: 2521.8543 - coeff_determination: -0.0920 - val_loss: 3464.4121 - val_coeff_determination: -13.2087
# Epoch 98/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2490.5511 - coeff_determination: -0.0636 - val_loss: 3160.7790 - val_coeff_determination: -2.7028
# Epoch 99/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2514.9845 - coeff_determination: -0.5441 - val_loss: 3161.9638 - val_coeff_determination: -3.1818
# Epoch 100/200
# 23652/23652 [==============================] - 9s 364us/step - loss: 2517.5057 - coeff_determination: -0.1664 - val_loss: 3199.9370 - val_coeff_determination: -7.8531
# Epoch 101/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2492.5904 - coeff_determination: -0.5823 - val_loss: 3079.9339 - val_coeff_determination: -5.8047
# Epoch 102/200
# 23652/23652 [==============================] - 9s 367us/step - loss: 2514.3715 - coeff_determination: 0.0030 - val_loss: 3105.7515 - val_coeff_determination: -7.1299
# Epoch 103/200
# 23652/23652 [==============================] - 9s 367us/step - loss: 2478.9749 - coeff_determination: -0.3618 - val_loss: 2914.4500 - val_coeff_determination: -4.0738
# Epoch 104/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2540.0534 - coeff_determination: -6.5723 - val_loss: 2908.2382 - val_coeff_determination: -2.6812
# Epoch 105/200
# 23652/23652 [==============================] - 9s 364us/step - loss: 2485.7721 - coeff_determination: -0.5257 - val_loss: 3884.7280 - val_coeff_determination: -25.1921
# Epoch 106/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2524.1440 - coeff_determination: -0.3246 - val_loss: 3315.7908 - val_coeff_determination: -5.0434
# Epoch 107/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2513.1451 - coeff_determination: -7.6295 - val_loss: 3297.6800 - val_coeff_determination: -14.9444
# Epoch 108/200
# 23652/23652 [==============================] - 9s 368us/step - loss: 2500.1068 - coeff_determination: -23.9059 - val_loss: 2513.9316 - val_coeff_determination: -1.2909
# Epoch 109/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2509.2602 - coeff_determination: -0.8140 - val_loss: 3880.8035 - val_coeff_determination: -23.7879
# Epoch 110/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2514.2441 - coeff_determination: -1310156698.6457 - val_loss: 2854.6067 - val_coeff_determination: -3.2881
# Epoch 111/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2531.2204 - coeff_determination: -0.1692 - val_loss: 2852.0957 - val_coeff_determination: -2.3168
# Epoch 112/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2555.6103 - coeff_determination: -1.5863 - val_loss: 3007.2180 - val_coeff_determination: -3.7378
# Epoch 113/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2484.8612 - coeff_determination: -0.4605 - val_loss: 3251.0710 - val_coeff_determination: -6.9533
# Epoch 114/200
# 23652/23652 [==============================] - 9s 370us/step - loss: 2505.7854 - coeff_determination: -0.1203 - val_loss: 2884.0185 - val_coeff_determination: -3.9335
# Epoch 115/200
# 23652/23652 [==============================] - 9s 385us/step - loss: 2483.8438 - coeff_determination: -1454785431721.1511 - val_loss: 2718.9304 - val_coeff_determination: -2.7307
# Epoch 116/200
# 23652/23652 [==============================] - 9s 389us/step - loss: 2472.9168 - coeff_determination: -0.2250 - val_loss: 2750.4699 - val_coeff_determination: -2.2531
# Epoch 117/200
# 23652/23652 [==============================] - 9s 384us/step - loss: 2468.8253 - coeff_determination: -30.1053 - val_loss: 2809.6270 - val_coeff_determination: -2.9680
# Epoch 118/200
# 23652/23652 [==============================] - 9s 382us/step - loss: 2500.1489 - coeff_determination: -5.7232 - val_loss: 3122.1989 - val_coeff_determination: -5.6325
# Epoch 119/200
# 23652/23652 [==============================] - 9s 392us/step - loss: 2485.9267 - coeff_determination: -0.0475 - val_loss: 2807.6660 - val_coeff_determination: -3.2975
# Epoch 120/200
# 23652/23652 [==============================] - 9s 388us/step - loss: 2545.3714 - coeff_determination: -1.5233 - val_loss: 3048.6479 - val_coeff_determination: -3.7659
# Epoch 121/200
# 23652/23652 [==============================] - 9s 380us/step - loss: 2467.9858 - coeff_determination: -0.6873 - val_loss: 2877.2896 - val_coeff_determination: -2.4285
# Epoch 122/200
# 23652/23652 [==============================] - 9s 388us/step - loss: 2482.0307 - coeff_determination: -0.4004 - val_loss: 2987.3257 - val_coeff_determination: -5.6219
# Epoch 123/200
# 23652/23652 [==============================] - 9s 384us/step - loss: 2513.1986 - coeff_determination: -1.4289 - val_loss: 3017.7104 - val_coeff_determination: -3.7364
# Epoch 124/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2480.1410 - coeff_determination: -0.3957 - val_loss: 3074.2057 - val_coeff_determination: -5.0465
# Epoch 125/200
# 23652/23652 [==============================] - 9s 364us/step - loss: 2462.1702 - coeff_determination: -0.2471 - val_loss: 3179.6720 - val_coeff_determination: -5.7322
# Epoch 126/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2563.6868 - coeff_determination: -448.9746 - val_loss: 3146.0006 - val_coeff_determination: -5.8534
# Epoch 127/200
# 23652/23652 [==============================] - 9s 367us/step - loss: 2454.0862 - coeff_determination: -0.2231 - val_loss: 3313.0478 - val_coeff_determination: -11.0457
# Epoch 128/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2436.2015 - coeff_determination: 0.0219 - val_loss: 4034.7041 - val_coeff_determination: -34.7681
# Epoch 129/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2472.0341 - coeff_determination: -10810543692.8807 - val_loss: 3067.8004 - val_coeff_determination: -5.3701
# Epoch 130/200
# 23652/23652 [==============================] - 9s 362us/step - loss: 2460.8598 - coeff_determination: -1.2495 - val_loss: 2880.6703 - val_coeff_determination: -3.6120
# Epoch 131/200
# 23652/23652 [==============================] - 9s 368us/step - loss: 2469.0218 - coeff_determination: -0.1446 - val_loss: 2944.3505 - val_coeff_determination: -8.9143
# Epoch 132/200
# 23652/23652 [==============================] - 9s 364us/step - loss: 2486.8999 - coeff_determination: -0.7221 - val_loss: 2658.2529 - val_coeff_determination: -10.6165
# Epoch 133/200
# 23652/23652 [==============================] - 9s 381us/step - loss: 2488.2808 - coeff_determination: -19663.5245 - val_loss: 3247.0087 - val_coeff_determination: -6.4272
# Epoch 134/200
# 23652/23652 [==============================] - 9s 386us/step - loss: 2434.8108 - coeff_determination: -4.0839 - val_loss: 3201.9195 - val_coeff_determination: -8.3804
# Epoch 135/200
# 23652/23652 [==============================] - 9s 386us/step - loss: 2465.2565 - coeff_determination: -92.6418 - val_loss: 3462.0059 - val_coeff_determination: -18.5853
# Epoch 136/200
# 23652/23652 [==============================] - 9s 380us/step - loss: 2420.6193 - coeff_determination: -0.5222 - val_loss: 2662.0900 - val_coeff_determination: -1.3112
# Epoch 137/200
# 23652/23652 [==============================] - 9s 384us/step - loss: 2458.1287 - coeff_determination: -1.4114 - val_loss: 3278.5759 - val_coeff_determination: -6.6375
# Epoch 138/200
# 23652/23652 [==============================] - 9s 379us/step - loss: 2435.8501 - coeff_determination: -0.0428 - val_loss: 3883.4425 - val_coeff_determination: -53.9995
# Epoch 139/200
# 23652/23652 [==============================] - 9s 384us/step - loss: 2482.4434 - coeff_determination: -1.1830 - val_loss: 3163.3950 - val_coeff_determination: -8.0525
# Epoch 140/200
# 23652/23652 [==============================] - 9s 380us/step - loss: 2507.0750 - coeff_determination: -67.1967 - val_loss: 2616.5788 - val_coeff_determination: -2.3250
# Epoch 141/200
# 23652/23652 [==============================] - 9s 379us/step - loss: 2411.4399 - coeff_determination: -0.3260 - val_loss: 2915.5055 - val_coeff_determination: -3.8031
# Epoch 142/200
# 23652/23652 [==============================] - 9s 377us/step - loss: 2499.0668 - coeff_determination: -5.0024 - val_loss: 2694.7026 - val_coeff_determination: -1.7551
# Epoch 143/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2472.4294 - coeff_determination: -0.3662 - val_loss: 3052.3476 - val_coeff_determination: -6.5890
# Epoch 144/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 
# 23652/23652 [==============================] - 9s 393us/step - loss: 2417.3017 - coeff_determination: -0.6382 - val_loss: 3640.5680 - val_coeff_determination: -18.7123
# Epoch 181/200
# 23652/23652 [==============================] - 9s 385us/step - loss: 2397.0331 - coeff_determination: -0.5365 - val_loss: 3828.9205 - val_coeff_determination: -26.0293
# Epoch 182/200
# 23652/23652 [==============================] - 9s 386us/step - loss: 2364.8977 - coeff_determination: -0.5232 - val_loss: 3072.1799 - val_coeff_determination: -5.4034
# Epoch 183/200
# 23652/23652 [==============================] - 9s 368us/step - loss: 2405.7199 - coeff_determination: -2.5046 - val_loss: 3050.9783 - val_coeff_determination: -9.1097
# Epoch 184/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2390.9802 - coeff_determination: -3.0223 - val_loss: 3090.0511 - val_coeff_determination: -14.1551
# Epoch 185/200
# 23652/23652 [==============================] - 9s 364us/step - loss: 2446.7499 - coeff_determination: -3.0830 - val_loss: 3240.1018 - val_coeff_determination: -9.0929
# Epoch 186/200
# 23652/23652 [==============================] - 9s 368us/step - loss: 2363.6192 - coeff_determination: -0.4704 - val_loss: 2956.1085 - val_coeff_determination: -6.2594
# Epoch 187/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2409.2283 - coeff_determination: -1.1273 - val_loss: 2919.9184 - val_coeff_determination: -7.4446
# Epoch 188/200
# 23652/23652 [==============================] - 9s 361us/step - loss: 2399.4132 - coeff_determination: -1.0742 - val_loss: 2905.3544 - val_coeff_determination: -8.6366
# Epoch 189/200
# 23652/23652 [==============================] - 9s 364us/step - loss: 2402.2663 - coeff_determination: -1.3577 - val_loss: 3475.3810 - val_coeff_determination: -13.1360
# Epoch 190/200
# 23652/23652 [==============================] - 9s 364us/step - loss: 2420.3149 - coeff_determination: -2066.9942 - val_loss: 2606.6341 - val_coeff_determination: -2.9375
# Epoch 191/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2379.0726 - coeff_determination: -0.0798 - val_loss: 2972.3935 - val_coeff_determination: -4.4968
# Epoch 192/200
# 23652/23652 [==============================] - 9s 367us/step - loss: 2431.6590 - coeff_determination: -9271596.6661 - val_loss: 3121.7135 - val_coeff_determination: -9.8580
# Epoch 193/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2396.8352 - coeff_determination: -100.3218 - val_loss: 2737.9064 - val_coeff_determination: -4.1024
# Epoch 194/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2368.4333 - coeff_determination: -0.1437 - val_loss: 3006.3737 - val_coeff_determination: -6.3360
# Epoch 195/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2370.4869 - coeff_determination: -2.4300 - val_loss: 3462.4127 - val_coeff_determination: -19.1340
# Epoch 196/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2362.7650 - coeff_determination: -0.1938 - val_loss: 2986.9966 - val_coeff_determination: -14.3538
# Epoch 197/200
# 23652/23652 [==============================] - 9s 363us/step - loss: 2322.4204 - coeff_determination: -2.0783 - val_loss: 3444.9345 - val_coeff_determination: -13.4605
# Epoch 198/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2365.1623 - coeff_determination: -1.7236 - val_loss: 4185.5090 - val_coeff_determination: -32.3719
# Epoch 199/200
# 23652/23652 [==============================] - 9s 365us/step - loss: 2353.7725 - coeff_determination: -0.4957 - val_loss: 3953.7079 - val_coeff_determination: -32.3382
# Epoch 200/200
# 23652/23652 [==============================] - 9s 366us/step - loss: 2362.6729 - coeff_determination: -5.3845 - val_loss: 3320.4880 - val_coeff_determination: -12.5549
