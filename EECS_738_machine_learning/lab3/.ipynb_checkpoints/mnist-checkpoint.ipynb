# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Flatten, BatchNormalization
from tensorflow.keras.models import Model, Sequential, model_from_json
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
nsamples, nx, ny = x_train.shape
x_train_d2 = x_train.reshape((nsamples, nx * ny))
x_train_normed = StandardScaler().fit_transform(x_train_d2)

nsamples, nx, ny = x_test.shape
x_test_d2 = x_test.reshape((nsamples, nx * ny))
x_test_normed = StandardScaler().fit_transform(x_test_d2)

# %%
y_train_ohe = pd.get_dummies(y_train).as_matrix()
y_test_ohe = pd.get_dummies(y_test).as_matrix()

# %% [markdown]
# Baseline model

# %%
model_sequences = [
    keras.layers.Dense(units=32, activation='relu', input_shape=x_train_normed.shape[1:]),
    keras.layers.Dense(units=32, activation='relu', input_shape=x_train_normed.shape[1:]),
]

model_sequences.append(Dense(units=10, name='output', activation='softmax'))
nn_model = keras.models.Sequential(model_sequences)
print(nn_model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                1056
# _________________________________________________________________
# output (Dense)               (None, 10)                330
# =================================================================
# Total params: 26,506
# Trainable params: 26,506
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# %%time
nn_model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
history = nn_model.fit(x_train_normed, y_train_ohe, validation_data=(x_test_normed, y_test_ohe), epochs=20, batch_size=64, verbose=1)
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.7474 - acc: 0.7875 - val_loss: 0.3449 - val_acc: 0.9005
# Epoch 2/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.3018 - acc: 0.9123 - val_loss: 0.2652 - val_acc: 0.9236
# Epoch 3/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.2428 - acc: 0.9281 - val_loss: 0.2324 - val_acc: 0.9327
# Epoch 4/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.2112 - acc: 0.9377 - val_loss: 0.2118 - val_acc: 0.9371
# Epoch 5/20
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.1897 - acc: 0.9438 - val_loss: 0.1977 - val_acc: 0.9414
# Epoch 6/20
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.1737 - acc: 0.9483 - val_loss: 0.1879 - val_acc: 0.9451
# Epoch 7/20
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.1607 - acc: 0.9523 - val_loss: 0.1789 - val_acc: 0.9471
# Epoch 8/20
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.1500 - acc: 0.9550 - val_loss: 0.1714 - val_acc: 0.9483
# Epoch 9/20
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.1406 - acc: 0.9580 - val_loss: 0.1667 - val_acc: 0.9519
# Epoch 10/20
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1326 - acc: 0.9612 - val_loss: 0.1601 - val_acc: 0.9532
# Epoch 11/20
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.1256 - acc: 0.9632 - val_loss: 0.1556 - val_acc: 0.9550
# Epoch 12/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1192 - acc: 0.9650 - val_loss: 0.1537 - val_acc: 0.9561
# Epoch 13/20
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1136 - acc: 0.9667 - val_loss: 0.1495 - val_acc: 0.9569
# Epoch 14/20
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.1086 - acc: 0.9688 - val_loss: 0.1472 - val_acc: 0.9586
# Epoch 15/20
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1039 - acc: 0.9698 - val_loss: 0.1459 - val_acc: 0.9584
# Epoch 16/20
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0994 - acc: 0.9712 - val_loss: 0.1438 - val_acc: 0.9594
# Epoch 17/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0956 - acc: 0.9723 - val_loss: 0.1422 - val_acc: 0.9595
# Epoch 18/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0917 - acc: 0.9737 - val_loss: 0.1405 - val_acc: 0.9613
# Epoch 19/20
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0884 - acc: 0.9742 - val_loss: 0.1399 - val_acc: 0.9604
# Epoch 20/20
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.0851 - acc: 0.9752 - val_loss: 0.1386 - val_acc: 0.9613
# CPU times: user 1min 4s, sys: 8.84 s, total: 1min 13s
# Wall time: 45.8 s

# %%
def save_keras_model(model, history, file_name):
    model_json = model.to_json()
    with open("./models/{}.json".format(file_name), 'w') as json_file:
        json_file.write(model_json)
    model.save_weights("./models/{}.h5".format(file_name))
    with open('./models/{}.history'.format(file_name), 'wb') as file_history:
        pickle.dump(history.history, file_history)
    print("model saved")
save_keras_model(nn_model, history, 'base_model')
# Out:
# model saved

# %% [markdown]
# Model with 64 neurons

# %%
model_sequences = [
    keras.layers.Dense(units=64, activation='relu', input_shape=x_train_normed.shape[1:]),
    keras.layers.Dense(units=64, activation='relu', input_shape=x_train_normed.shape[1:]),
]

model_sequences.append(Dense(units=10, name='output', activation='softmax'))
nn_model_64 = keras.models.Sequential(model_sequences)
print(nn_model_64.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                4160
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# %%time
nn_model_64.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
history = nn_model_64.fit(x_train_normed, y_train_ohe, validation_data=(x_test_normed, y_test_ohe), epochs=20, batch_size=64, verbose=1)
save_keras_model(nn_model_64, history, 'model_64_n')
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.7306 - acc: 0.7913 - val_loss: 0.3328 - val_acc: 0.9039
# Epoch 2/20
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.2856 - acc: 0.9179 - val_loss: 0.2483 - val_acc: 0.9271
# Epoch 3/20
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.2224 - acc: 0.9351 - val_loss: 0.2116 - val_acc: 0.9382
# Epoch 4/20
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.1888 - acc: 0.9440 - val_loss: 0.1919 - val_acc: 0.9436
# Epoch 5/20
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.1660 - acc: 0.9503 - val_loss: 0.1778 - val_acc: 0.9487
# Epoch 6/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1493 - acc: 0.9564 - val_loss: 0.1669 - val_acc: 0.9523
# Epoch 7/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1361 - acc: 0.9600 - val_loss: 0.1587 - val_acc: 0.9543
# Epoch 8/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1253 - acc: 0.9632 - val_loss: 0.1532 - val_acc: 0.9559
# Epoch 9/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1163 - acc: 0.9657 - val_loss: 0.1505 - val_acc: 0.9562
# Epoch 10/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1084 - acc: 0.9683 - val_loss: 0.1442 - val_acc: 0.9585
# Epoch 11/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1015 - acc: 0.9712 - val_loss: 0.1394 - val_acc: 0.9597
# Epoch 12/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0954 - acc: 0.9724 - val_loss: 0.1350 - val_acc: 0.9613
# Epoch 13/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0899 - acc: 0.9743 - val_loss: 0.1331 - val_acc: 0.9624
# Epoch 14/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0848 - acc: 0.9759 - val_loss: 0.1321 - val_acc: 0.9622
# Epoch 15/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0801 - acc: 0.9771 - val_loss: 0.1300 - val_acc: 0.9631
# Epoch 16/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0757 - acc: 0.9788 - val_loss: 0.1289 - val_acc: 0.9635
# Epoch 17/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0720 - acc: 0.9799 - val_loss: 0.1278 - val_acc: 0.9635
# Epoch 18/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0683 - acc: 0.9810 - val_loss: 0.1265 - val_acc: 0.9642
# Epoch 19/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0649 - acc: 0.9818 - val_loss: 0.1255 - val_acc: 0.9657
# Epoch 20/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0618 - acc: 0.9830 - val_loss: 0.1246 - val_acc: 0.9659
# model saved
# CPU times: user 1min 16s, sys: 10.4 s, total: 1min 26s
# Wall time: 51 s

# %% [markdown]
# Model with batch size 128

# %%
# %%time
model_sequences = [
    keras.layers.Dense(units=32, activation='relu', input_shape=x_train_normed.shape[1:]),
    keras.layers.Dense(units=32, activation='relu', input_shape=x_train_normed.shape[1:]),
]

model_sequences.append(Dense(units=10, name='output', activation='softmax'))
nn_model = keras.models.Sequential(model_sequences)
nn_model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
history_bs_128 = nn_model.fit(x_train_normed, y_train_ohe, validation_data=(x_test_normed, y_test_ohe), epochs=20, batch_size=128, verbose=1)
# save_keras_model(nn_model, history, 'model_64_n')
pd.DataFrame(history_bs_128.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 2s 32us/step - loss: 1.1135 - acc: 0.6704 - val_loss: 0.5376 - val_acc: 0.8515
# Epoch 2/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.4382 - acc: 0.8738 - val_loss: 0.3646 - val_acc: 0.8960
# Epoch 3/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.3298 - acc: 0.9024 - val_loss: 0.3074 - val_acc: 0.9107
# Epoch 4/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.2806 - acc: 0.9176 - val_loss: 0.2754 - val_acc: 0.9191
# Epoch 5/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.2506 - acc: 0.9265 - val_loss: 0.2543 - val_acc: 0.9263
# Epoch 6/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.2289 - acc: 0.9325 - val_loss: 0.2391 - val_acc: 0.9315
# Epoch 7/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.2123 - acc: 0.9375 - val_loss: 0.2259 - val_acc: 0.9354
# Epoch 8/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1989 - acc: 0.9413 - val_loss: 0.2166 - val_acc: 0.9385
# Epoch 9/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1877 - acc: 0.9443 - val_loss: 0.2086 - val_acc: 0.9410
# Epoch 10/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1782 - acc: 0.9473 - val_loss: 0.2023 - val_acc: 0.9422
# Epoch 11/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1699 - acc: 0.9501 - val_loss: 0.1970 - val_acc: 0.9435
# Epoch 12/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1629 - acc: 0.9523 - val_loss: 0.1915 - val_acc: 0.9454
# Epoch 13/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1563 - acc: 0.9550 - val_loss: 0.1872 - val_acc: 0.9476
# Epoch 14/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1505 - acc: 0.9561 - val_loss: 0.1830 - val_acc: 0.9479
# Epoch 15/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1454 - acc: 0.9575 - val_loss: 0.1807 - val_acc: 0.9487
# Epoch 16/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1405 - acc: 0.9589 - val_loss: 0.1782 - val_acc: 0.9508
# Epoch 17/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1362 - acc: 0.9603 - val_loss: 0.1756 - val_acc: 0.9509
# Epoch 18/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1321 - acc: 0.9615 - val_loss: 0.1735 - val_acc: 0.9518
# Epoch 19/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1282 - acc: 0.9630 - val_loss: 0.1712 - val_acc: 0.9518
# Epoch 20/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1245 - acc: 0.9637 - val_loss: 0.1688 - val_acc: 0.9534
# CPU times: user 43 s, sys: 5.02 s, total: 48 s
# Wall time: 29.6 s

# %% [markdown]
# Models with different learning rates

# %%
# %%time
model_sequences = [
    keras.layers.Dense(units=32, activation='relu', input_shape=x_train_normed.shape[1:]),
    keras.layers.Dense(units=32, activation='relu', input_shape=x_train_normed.shape[1:]),
]

model_sequences.append(Dense(units=10, name='output', activation='softmax'))
nn_model_lr = keras.models.Sequential(model_sequences)
sgd = SGD(lr=0.000001, momentum=0.9)
nn_model_lr.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
history = nn_model_lr.fit(x_train_normed, y_train_ohe, validation_data=(x_test_normed, y_test_ohe), epochs=20, batch_size=64, verbose=1)
save_keras_model(nn_model_lr, history, 'model_lr')
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 3s 51us/step - loss: 2.7551 - acc: 0.1054 - val_loss: 2.7427 - val_acc: 0.1061
# Epoch 2/20
# 60000/60000 [==============================] - 2s 36us/step - loss: 2.7171 - acc: 0.1099 - val_loss: 2.7061 - val_acc: 0.1103
# Epoch 3/20
# 60000/60000 [==============================] - 2s 37us/step - loss: 2.6811 - acc: 0.1154 - val_loss: 2.6714 - val_acc: 0.1152
# Epoch 4/20
# 60000/60000 [==============================] - 2s 37us/step - loss: 2.6470 - acc: 0.1205 - val_loss: 2.6385 - val_acc: 0.1225
# Epoch 5/20
# 60000/60000 [==============================] - 3s 45us/step - loss: 2.6146 - acc: 0.1270 - val_loss: 2.6072 - val_acc: 0.1283
# Epoch 6/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.5837 - acc: 0.1332 - val_loss: 2.5772 - val_acc: 0.1358
# Epoch 7/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.5542 - acc: 0.1397 - val_loss: 2.5487 - val_acc: 0.1426
# Epoch 8/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.5260 - acc: 0.1474 - val_loss: 2.5213 - val_acc: 0.1488
# Epoch 9/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.4990 - acc: 0.1552 - val_loss: 2.4950 - val_acc: 0.1559
# Epoch 10/20
# 60000/60000 [==============================] - 2s 39us/step - loss: 2.4731 - acc: 0.1629 - val_loss: 2.4698 - val_acc: 0.1635
# Epoch 11/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.4483 - acc: 0.1706 - val_loss: 2.4456 - val_acc: 0.1706
# Epoch 12/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.4244 - acc: 0.1779 - val_loss: 2.4222 - val_acc: 0.1784
# Epoch 13/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.4013 - acc: 0.1860 - val_loss: 2.3997 - val_acc: 0.1854
# Epoch 14/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.3791 - acc: 0.1939 - val_loss: 2.3780 - val_acc: 0.1920
# Epoch 15/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.3577 - acc: 0.2006 - val_loss: 2.3570 - val_acc: 0.1993
# Epoch 16/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.3371 - acc: 0.2075 - val_loss: 2.3367 - val_acc: 0.2067
# Epoch 17/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.3171 - acc: 0.2152 - val_loss: 2.3170 - val_acc: 0.2143
# Epoch 18/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.2977 - acc: 0.2218 - val_loss: 2.2980 - val_acc: 0.2205
# Epoch 19/20
# 60000/60000 [==============================] - 2s 38us/step - loss: 2.2790 - acc: 0.2295 - val_loss: 2.2796 - val_acc: 0.2278
# Epoch 20/20
# 60000/60000 [==============================] - 2s 39us/step - loss: 2.2608 - acc: 0.2362 - val_loss: 2.2617 - val_acc: 0.2366
# model saved
# CPU times: user 1min 8s, sys: 9.67 s, total: 1min 18s
# Wall time: 47.5 s

# %% [markdown]
# Model with batch size 32

# %%
model_sequences = [
    keras.layers.Dense(units=32, activation='relu', input_shape=x_train_normed.shape[1:]),
    keras.layers.Dense(units=32, activation='relu', input_shape=x_train_normed.shape[1:]),
]

model_sequences.append(Dense(units=10, name='output', activation='softmax'))
nn_model = keras.models.Sequential(model_sequences)
nn_model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
# %%time
history_bs_32 = nn_model.fit(x_train_normed, y_train_ohe, validation_data=(x_test_normed, y_test_ohe), epochs=20, batch_size=32, verbose=1)
# save_keras_model(nn_model, history, 'model_64_n')
pd.DataFrame(history_bs_32.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.5668 - acc: 0.8365 - val_loss: 0.2792 - val_acc: 0.9148
# Epoch 2/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.2404 - acc: 0.9287 - val_loss: 0.2181 - val_acc: 0.9351
# Epoch 3/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.1919 - acc: 0.9427 - val_loss: 0.1942 - val_acc: 0.9410
# Epoch 4/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.1651 - acc: 0.9514 - val_loss: 0.1799 - val_acc: 0.9466
# Epoch 5/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.1465 - acc: 0.9572 - val_loss: 0.1711 - val_acc: 0.9500
# Epoch 6/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.1330 - acc: 0.9608 - val_loss: 0.1595 - val_acc: 0.9534
# Epoch 7/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1216 - acc: 0.9639 - val_loss: 0.1558 - val_acc: 0.9554
# Epoch 8/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1124 - acc: 0.9673 - val_loss: 0.1504 - val_acc: 0.9576
# Epoch 9/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1045 - acc: 0.9693 - val_loss: 0.1507 - val_acc: 0.9581
# Epoch 10/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0979 - acc: 0.9711 - val_loss: 0.1472 - val_acc: 0.9590
# Epoch 11/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0915 - acc: 0.9729 - val_loss: 0.1453 - val_acc: 0.9586
# Epoch 12/20
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0861 - acc: 0.9747 - val_loss: 0.1421 - val_acc: 0.9608
# Epoch 13/20
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.0813 - acc: 0.9759 - val_loss: 0.1432 - val_acc: 0.9600
# Epoch 14/20
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.0770 - acc: 0.9775 - val_loss: 0.1402 - val_acc: 0.9612
# Epoch 15/20
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.0729 - acc: 0.9788 - val_loss: 0.1400 - val_acc: 0.9606
# Epoch 16/20
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.0694 - acc: 0.9801 - val_loss: 0.1409 - val_acc: 0.9621
# Epoch 17/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0657 - acc: 0.9809 - val_loss: 0.1438 - val_acc: 0.9622
# Epoch 18/20
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.0628 - acc: 0.9818 - val_loss: 0.1407 - val_acc: 0.9628
# Epoch 19/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0599 - acc: 0.9832 - val_loss: 0.1422 - val_acc: 0.9619
# Epoch 20/20
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.0573 - acc: 0.9841 - val_loss: 0.1400 - val_acc: 0.9626
# CPU times: user 1min 47s, sys: 16.6 s, total: 2min 4s
# Wall time: 1min 15s
