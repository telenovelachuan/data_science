# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics.classification import accuracy_score
from dbn import SupervisedDBNClassification

# %%
df, target = load_iris(return_X_y=True)
df = pd.DataFrame(df, columns=["sepal length (cm)","sepal width (cm)","petal length (cm)","petal width (cm)"])
df["label"] = target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      label
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2
#
# [150 rows x 5 columns]

# %%
# Normalize
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X = df.drop(columns=["label"])
Y = df["label"]
X = ss.fit_transform(X)

# %%
#x, y = load_iris(return_X_y=True)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)


def evaluate_model(model_func, model_name, x_train=X_train, x_test=X_test, y_train=Y_train, y_test=Y_test):
    #gnb = GaussianNB()
    model = model_func()
    y_pred1 = model.fit(x_train, y_train).predict(x_test)

    x_train, x_test = x_test, x_train
    y_train, y_test = y_test, y_train
    #gnb = GaussianNB()
    model = model_func()
    y_pred2 = model.fit(x_train, y_train).predict(x_test)

    y_pred = np.round(np.append(y_pred2, y_pred1))
    y_true = np.append(y_test, y_train)
    print(f"Evaluating {model_name} model")
    print(f"Accuracy: {round((y_pred == y_true).sum() / len(y), 4)}")
    print(f"Confusion Matrix:\n {confusion_matrix(y_true, y_pred, labels=[0, 1, 2])}")

# %%
dbn_clf = SupervisedDBNClassification(hidden_layers_structure=[256, 256], verbose=False,
    learning_rate_rbm=0.05,
    learning_rate=0.1,
    n_epochs_rbm=10,
    n_iter_backprop=100,
    batch_size=32,
    activation_function='relu',
    dropout_p=0.2)

#     dbn_clf.fit(x_train, y_train)
#     y_pred = dbn_clf.predict(x_test)
#     print('Done.\nAccuracy: %f' % accuracy_score(y_test, y_pred))

# %%
X_test.shape
# Out:
# (30, 4)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(dbn_clf, X_train, Y_train, cv=5)
scores
# Out:
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 2.791231
# >> Epoch 2 finished 	RBM Reconstruction error 2.781086
# >> Epoch 3 finished 	RBM Reconstruction error 2.771000
# >> Epoch 4 finished 	RBM Reconstruction error 2.761839
# >> Epoch 5 finished 	RBM Reconstruction error 2.752735
# >> Epoch 6 finished 	RBM Reconstruction error 2.743100
# >> Epoch 7 finished 	RBM Reconstruction error 2.733961
# >> Epoch 8 finished 	RBM Reconstruction error 2.725399
# >> Epoch 9 finished 	RBM Reconstruction error 2.716631
# >> Epoch 10 finished 	RBM Reconstruction error 2.708018
# >> Epoch 1 finished 	RBM Reconstruction error 6.130892
# >> Epoch 2 finished 	RBM Reconstruction error 6.030681
# >> Epoch 3 finished 	RBM Reconstruction error 5.935441
# >> Epoch 4 finished 	RBM Reconstruction error 5.844534
# >> Epoch 5 finished 	RBM Reconstruction error 5.758252
# >> Epoch 6 finished 	RBM Reconstruction error 5.675633
# >> Epoch 7 finished 	RBM Reconstruction error 5.596196
# >> Epoch 8 finished 	RBM Reconstruction error 5.520224
# >> Epoch 9 finished 	RBM Reconstruction error 5.445871
# >> Epoch 10 finished 	RBM Reconstruction error 5.373788
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 3.356672
# >> Epoch 2 finished 	ANN training loss 3.348668
# >> Epoch 3 finished 	ANN training loss 3.341589
# >> Epoch 4 finished 	ANN training loss 3.334011
# >> Epoch 5 finished 	ANN training loss 3.327121
# >> Epoch 6 finished 	ANN training loss 3.320900
# >> Epoch 7 finished 	ANN training loss 3.315499
# >> Epoch 8 finished 	ANN training loss 3.310733
# >> Epoch 9 finished 	ANN training loss 3.305449
# >> Epoch 10 finished 	ANN training loss 3.299415
# >> Epoch 11 finished 	ANN training loss 3.294207
# >> Epoch 12 finished 	ANN training loss 3.289496
# >> Epoch 13 finished 	ANN training loss 3.285030
# >> Epoch 14 finished 	ANN training loss 3.280608
# >> Epoch 15 finished 	ANN training loss 3.276781
# >> Epoch 16 finished 	ANN training loss 3.274201
# >> Epoch 17 finished 	ANN training loss 3.270432
# >> Epoch 18 finished 	ANN training loss 3.266982
# >> Epoch 19 finished 	ANN training loss 3.262361
# >> Epoch 20 finished 	ANN training loss 3.259281
# >> Epoch 21 finished 	ANN training loss 3.256893
# >> Epoch 22 finished 	ANN training loss 3.253548
# >> Epoch 23 finished 	ANN training loss 3.250733
# >> Epoch 24 finished 	ANN training loss 3.249270
# >> Epoch 25 finished 	ANN training loss 3.245592
# >> Epoch 26 finished 	ANN training loss 3.243546
# >> Epoch 27 finished 	ANN training loss 3.241092
# >> Epoch 28 finished 	ANN training loss 3.239303
# >> Epoch 29 finished 	ANN training loss 3.236220
# >> Epoch 30 finished 	ANN training loss 3.234421
# >> Epoch 31 finished 	ANN training loss 3.232989
# >> Epoch 32 finished 	ANN training loss 3.230307
# >> Epoch 33 finished 	ANN training loss 3.228569
# >> Epoch 34 finished 	ANN training loss 3.227136
# >> Epoch 35 finished 	ANN training loss 3.225306
# >> Epoch 36 finished 	ANN training loss 3.223142
# >> Epoch 37 finished 	ANN training loss 3.223009
# >> Epoch 38 finished 	ANN training loss 3.219978
# >> Epoch 39 finished 	ANN training loss 3.218240
# >> Epoch 40 finished 	ANN training loss 3.217041
# >> Epoch 41 finished 	ANN training loss 3.215787
# >> Epoch 42 finished 	ANN training loss 3.214223
# >> Epoch 43 finished 	ANN training loss 3.212485
# >> Epoch 44 finished 	ANN training loss 3.211434
# >> Epoch 45 finished 	ANN training loss 3.209696
# >> Epoch 46 finished 	ANN training loss 3.209360
# >> Epoch 47 finished 	ANN training loss 3.206986
# >> Epoch 48 finished 	ANN training loss 3.206261
# >> Epoch 49 finished 	ANN training loss 3.204718
# >> Epoch 50 finished 	ANN training loss 3.204495
# >> Epoch 51 finished 	ANN training loss 3.202368
# >> Epoch 52 finished 	ANN training loss 3.201365
# >> Epoch 53 finished 	ANN training loss 3.201955
# >> Epoch 54 finished 	ANN training loss 3.199430
# >> Epoch 55 finished 	ANN training loss 3.197820
# >> Epoch 56 finished 	ANN training loss 3.196537
# >> Epoch 57 finished 	ANN training loss 3.195850
# >> Epoch 58 finished 	ANN training loss 3.194777
# >> Epoch 59 finished 	ANN training loss 3.193583
# >> Epoch 60 finished 	ANN training loss 3.192707
# >> Epoch 61 finished 	ANN training loss 3.191725
# >> Epoch 62 finished 	ANN training loss 3.191039
# >> Epoch 63 finished 	ANN training loss 3.190189
# >> Epoch 64 finished 	ANN training loss 3.188580
# >> Epoch 65 finished 	ANN training loss 3.187843
# >> Epoch 66 finished 	ANN training loss 3.186925
# >> Epoch 67 finished 	ANN training loss 3.185661
# >> Epoch 68 finished 	ANN training loss 3.184873
# >> Epoch 69 finished 	ANN training loss 3.184375
# >> Epoch 70 finished 	ANN training loss 3.183470
# >> Epoch 71 finished 	ANN training loss 3.181908
# >> Epoch 72 finished 	ANN training loss 3.181304
# >> Epoch 73 finished 	ANN training loss 3.180597
# >> Epoch 74 finished 	ANN training loss 3.179600
# >> Epoch 75 finished 	ANN training loss 3.179074
# >> Epoch 76 finished 	ANN training loss 3.178215
# >> Epoch 77 finished 	ANN training loss 3.176372
# >> Epoch 78 finished 	ANN training loss 3.175835
# >> Epoch 79 finished 	ANN training loss 3.174846
# >> Epoch 80 finished 	ANN training loss 3.175058
# >> Epoch 81 finished 	ANN training loss 3.174193
# >> Epoch 82 finished 	ANN training loss 3.172627
# >> Epoch 83 finished 	ANN training loss 3.172541
# >> Epoch 84 finished 	ANN training loss 3.170972
# >> Epoch 85 finished 	ANN training loss 3.170221
# >> Epoch 86 finished 	ANN training loss 3.169255
# >> Epoch 87 finished 	ANN training loss 3.168020
# >> Epoch 88 finished 	ANN training loss 3.167345
# >> Epoch 89 finished 	ANN training loss 3.166907
# >> Epoch 90 finished 	ANN training loss 3.165899
# >> Epoch 91 finished 	ANN training loss 3.165284
# >> Epoch 92 finished 	ANN training loss 3.164024
# >> Epoch 93 finished 	ANN training loss 3.163922
# >> Epoch 94 finished 	ANN training loss 3.162189
# >> Epoch 95 finished 	ANN training loss 3.161221
# >> Epoch 96 finished 	ANN training loss 3.160478
# >> Epoch 97 finished 	ANN training loss 3.160023
# >> Epoch 98 finished 	ANN training loss 3.158896
# >> Epoch 99 finished 	ANN training loss 3.158460
# >> Epoch 100 finished 	ANN training loss 3.157951
# [END] Fine tuning step
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 3.567363
# >> Epoch 2 finished 	RBM Reconstruction error 3.540559
# >> Epoch 3 finished 	RBM Reconstruction error 3.514398
# >> Epoch 4 finished 	RBM Reconstruction error 3.488487
# >> Epoch 5 finished 	RBM Reconstruction error 3.463124
# >> Epoch 6 finished 	RBM Reconstruction error 3.437587
# >> Epoch 7 finished 	RBM Reconstruction error 3.413164
# >> Epoch 8 finished 	RBM Reconstruction error 3.389306
# >> Epoch 9 finished 	RBM Reconstruction error 3.366342
# >> Epoch 10 finished 	RBM Reconstruction error 3.343593
# >> Epoch 1 finished 	RBM Reconstruction error 5.742510
# >> Epoch 2 finished 	RBM Reconstruction error 5.643858
# >> Epoch 3 finished 	RBM Reconstruction error 5.548900
# >> Epoch 4 finished 	RBM Reconstruction error 5.458924
# >> Epoch 5 finished 	RBM Reconstruction error 5.372938
# >> Epoch 6 finished 	RBM Reconstruction error 5.291373
# >> Epoch 7 finished 	RBM Reconstruction error 5.213330
# >> Epoch 8 finished 	RBM Reconstruction error 5.138323
# >> Epoch 9 finished 	RBM Reconstruction error 5.067113
# >> Epoch 10 finished 	RBM Reconstruction error 4.998573
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 3.397559
# >> Epoch 2 finished 	ANN training loss 3.386339
# >> Epoch 3 finished 	ANN training loss 3.377019
# >> Epoch 4 finished 	ANN training loss 3.368336
# >> Epoch 5 finished 	ANN training loss 3.359279
# >> Epoch 6 finished 	ANN training loss 3.351227
# >> Epoch 7 finished 	ANN training loss 3.343603
# >> Epoch 8 finished 	ANN training loss 3.336671
# >> Epoch 9 finished 	ANN training loss 3.329850
# >> Epoch 10 finished 	ANN training loss 3.323190
# >> Epoch 11 finished 	ANN training loss 3.316943
# >> Epoch 12 finished 	ANN training loss 3.311079
# >> Epoch 13 finished 	ANN training loss 3.306160
# >> Epoch 14 finished 	ANN training loss 3.300495
# >> Epoch 15 finished 	ANN training loss 3.295191
# >> Epoch 16 finished 	ANN training loss 3.290896
# >> Epoch 17 finished 	ANN training loss 3.285970
# >> Epoch 18 finished 	ANN training loss 3.282462
# >> Epoch 19 finished 	ANN training loss 3.277626
# >> Epoch 20 finished 	ANN training loss 3.273432
# >> Epoch 21 finished 	ANN training loss 3.270165
# >> Epoch 22 finished 	ANN training loss 3.266358
# >> Epoch 23 finished 	ANN training loss 3.262941
# >> Epoch 24 finished 	ANN training loss 3.259664
# >> Epoch 25 finished 	ANN training loss 3.256743
# >> Epoch 26 finished 	ANN training loss 3.253414
# >> Epoch 27 finished 	ANN training loss 3.251594
# >> Epoch 28 finished 	ANN training loss 3.248013
# >> Epoch 29 finished 	ANN training loss 3.246014
# >> Epoch 30 finished 	ANN training loss 3.242918
# >> Epoch 31 finished 	ANN training loss 3.241444
# >> Epoch 32 finished 	ANN training loss 3.238348
# >> Epoch 33 finished 	ANN training loss 3.236352
# >> Epoch 34 finished 	ANN training loss 3.234166
# >> Epoch 35 finished 	ANN training loss 3.231501
# >> Epoch 36 finished 	ANN training loss 3.229655
# >> Epoch 37 finished 	ANN training loss 3.228003
# >> Epoch 38 finished 	ANN training loss 3.226097
# >> Epoch 39 finished 	ANN training loss 3.224739
# >> Epoch 40 finished 	ANN training loss 3.222230
# >> Epoch 41 finished 	ANN training loss 3.220634
# >> Epoch 42 finished 	ANN training loss 3.219795
# >> Epoch 43 finished 	ANN training loss 3.217776
# >> Epoch 44 finished 	ANN training loss 3.217333
# >> Epoch 45 finished 	ANN training loss 3.214949
# >> Epoch 46 finished 	ANN training loss 3.212913
# >> Epoch 47 finished 	ANN training loss 3.211387
# >> Epoch 48 finished 	ANN training loss 3.210291
# >> Epoch 49 finished 	ANN training loss 3.208904
# >> Epoch 50 finished 	ANN training loss 3.207816
# >> Epoch 51 finished 	ANN training loss 3.206511
# >> Epoch 52 finished 	ANN training loss 3.205142
# >> Epoch 53 finished 	ANN training loss 3.204241
# >> Epoch 54 finished 	ANN training loss 3.202491
# >> Epoch 55 finished 	ANN training loss 3.201268
# >> Epoch 56 finished 	ANN training loss 3.200924
# >> Epoch 57 finished 	ANN training loss 3.199352
# >> Epoch 58 finished 	ANN training loss 3.198883
# >> Epoch 59 finished 	ANN training loss 3.196992
# >> Epoch 60 finished 	ANN training loss 3.197138
# >> Epoch 61 finished 	ANN training loss 3.194602
# >> Epoch 62 finished 	ANN training loss 3.193971
# >> Epoch 63 finished 	ANN training loss 3.193600
# >> Epoch 64 finished 	ANN training loss 3.192019
# >> Epoch 65 finished 	ANN training loss 3.190615
# >> Epoch 66 finished 	ANN training loss 3.190231
# >> Epoch 67 finished 	ANN training loss 3.189225
# >> Epoch 68 finished 	ANN training loss 3.189612
# >> Epoch 69 finished 	ANN training loss 3.187300
# >> Epoch 70 finished 	ANN training loss 3.185961
# >> Epoch 71 finished 	ANN training loss 3.184888
# >> Epoch 72 finished 	ANN training loss 3.183868
# >> Epoch 73 finished 	ANN training loss 3.183149
# >> Epoch 74 finished 	ANN training loss 3.182845
# >> Epoch 75 finished 	ANN training loss 3.181669
# >> Epoch 76 finished 	ANN training loss 3.181389
# >> Epoch 77 finished 	ANN training loss 3.179395
# >> Epoch 78 finished 	ANN training loss 3.179478
# >> Epoch 79 finished 	ANN training loss 3.178138
# >> Epoch 80 finished 	ANN training loss 3.177826
# >> Epoch 81 finished 	ANN training loss 3.175917
# >> Epoch 82 finished 	ANN training loss 3.175508
# >> Epoch 83 finished 	ANN training loss 3.174587
# >> Epoch 84 finished 	ANN training loss 3.173823
# >> Epoch 85 finished 	ANN training loss 3.172482
# >> Epoch 86 finished 	ANN training loss 3.172118
# >> Epoch 87 finished 	ANN training loss 3.171400
# >> Epoch 88 finished 	ANN training loss 3.170592
# >> Epoch 89 finished 	ANN training loss 3.169327
# >> Epoch 90 finished 	ANN training loss 3.169434
# >> Epoch 91 finished 	ANN training loss 3.167635
# >> Epoch 92 finished 	ANN training loss 3.166946
# >> Epoch 93 finished 	ANN training loss 3.166230
# >> Epoch 94 finished 	ANN training loss 3.165232
# >> Epoch 95 finished 	ANN training loss 3.164920
# >> Epoch 96 finished 	ANN training loss 3.164311
# >> Epoch 97 finished 	ANN training loss 3.164193
# >> Epoch 98 finished 	ANN training loss 3.161900
# >> Epoch 99 finished 	ANN training loss 3.161322
# >> Epoch 100 finished 	ANN training loss 3.160580
# [END] Fine tuning step
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 3.088494
# >> Epoch 2 finished 	RBM Reconstruction error 3.072753
# >> Epoch 3 finished 	RBM Reconstruction error 3.057462
# >> Epoch 4 finished 	RBM Reconstruction error 3.041927
# >> Epoch 5 finished 	RBM Reconstruction error 3.027412
# >> Epoch 6 finished 	RBM Reconstruction error 3.012745
# >> Epoch 7 finished 	RBM Reconstruction error 2.998080
# >> Epoch 8 finished 	RBM Reconstruction error 2.983602
# >> Epoch 9 finished 	RBM Reconstruction error 2.969400
# >> Epoch 10 finished 	RBM Reconstruction error 2.955630
# >> Epoch 1 finished 	RBM Reconstruction error 5.609520
# >> Epoch 2 finished 	RBM Reconstruction error 5.525821
# >> Epoch 3 finished 	RBM Reconstruction error 5.445558
# >> Epoch 4 finished 	RBM Reconstruction error 5.367519
# >> Epoch 5 finished 	RBM Reconstruction error 5.292517
# >> Epoch 6 finished 	RBM Reconstruction error 5.219585
# >> Epoch 7 finished 	RBM Reconstruction error 5.148702
# >> Epoch 8 finished 	RBM Reconstruction error 5.080856
# >> Epoch 9 finished 	RBM Reconstruction error 5.015234
# >> Epoch 10 finished 	RBM Reconstruction error 4.951714
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 3.367987
# >> Epoch 2 finished 	ANN training loss 3.358441
# >> Epoch 3 finished 	ANN training loss 3.350495
# >> Epoch 4 finished 	ANN training loss 3.341430
# >> Epoch 5 finished 	ANN training loss 3.332177
# >> Epoch 6 finished 	ANN training loss 3.324142
# >> Epoch 7 finished 	ANN training loss 3.315840
# >> Epoch 8 finished 	ANN training loss 3.308892
# >> Epoch 9 finished 	ANN training loss 3.301223
# >> Epoch 10 finished 	ANN training loss 3.293653
# >> Epoch 11 finished 	ANN training loss 3.287239
# >> Epoch 12 finished 	ANN training loss 3.280760
# >> Epoch 13 finished 	ANN training loss 3.273482
# >> Epoch 14 finished 	ANN training loss 3.267073
# >> Epoch 15 finished 	ANN training loss 3.262387
# >> Epoch 16 finished 	ANN training loss 3.255737
# >> Epoch 17 finished 	ANN training loss 3.249034
# >> Epoch 18 finished 	ANN training loss 3.243826
# >> Epoch 19 finished 	ANN training loss 3.238252
# >> Epoch 20 finished 	ANN training loss 3.234073
# >> Epoch 21 finished 	ANN training loss 3.228088
# >> Epoch 22 finished 	ANN training loss 3.223365
# >> Epoch 23 finished 	ANN training loss 3.218776
# >> Epoch 24 finished 	ANN training loss 3.214008
# >> Epoch 25 finished 	ANN training loss 3.209725
# >> Epoch 26 finished 	ANN training loss 3.205575
# >> Epoch 27 finished 	ANN training loss 3.201011
# >> Epoch 28 finished 	ANN training loss 3.196991
# >> Epoch 29 finished 	ANN training loss 3.193019
# >> Epoch 30 finished 	ANN training loss 3.189367
# >> Epoch 31 finished 	ANN training loss 3.186021
# >> Epoch 32 finished 	ANN training loss 3.182698
# >> Epoch 33 finished 	ANN training loss 3.178832
# >> Epoch 34 finished 	ANN training loss 3.175812
# >> Epoch 35 finished 	ANN training loss 3.172414
# >> Epoch 36 finished 	ANN training loss 3.169974
# >> Epoch 37 finished 	ANN training loss 3.166712
# >> Epoch 38 finished 	ANN training loss 3.163933
# >> Epoch 39 finished 	ANN training loss 3.161101
# >> Epoch 40 finished 	ANN training loss 3.157889
# >> Epoch 41 finished 	ANN training loss 3.155164
# >> Epoch 42 finished 	ANN training loss 3.152848
# >> Epoch 43 finished 	ANN training loss 3.150450
# >> Epoch 44 finished 	ANN training loss 3.148075
# >> Epoch 45 finished 	ANN training loss 3.146007
# >> Epoch 46 finished 	ANN training loss 3.143232
# >> Epoch 47 finished 	ANN training loss 3.141090
# >> Epoch 48 finished 	ANN training loss 3.138727
# >> Epoch 49 finished 	ANN training loss 3.136758
# >> Epoch 50 finished 	ANN training loss 3.134683
# >> Epoch 51 finished 	ANN training loss 3.132529
# >> Epoch 52 finished 	ANN training loss 3.130684
# >> Epoch 53 finished 	ANN training loss 3.129286
# >> Epoch 54 finished 	ANN training loss 3.127137
# >> Epoch 55 finished 	ANN training loss 3.125458
# >> Epoch 56 finished 	ANN training loss 3.124199
# >> Epoch 57 finished 	ANN training loss 3.122063
# >> Epoch 58 finished 	ANN training loss 3.120903
# >> Epoch 59 finished 	ANN training loss 3.118773
# >> Epoch 60 finished 	ANN training loss 3.116951
# >> Epoch 61 finished 	ANN training loss 3.116142
# >> Epoch 62 finished 	ANN training loss 3.114503
# >> Epoch 63 finished 	ANN training loss 3.113456
# >> Epoch 64 finished 	ANN training loss 3.111404
# >> Epoch 65 finished 	ANN training loss 3.109808
# >> Epoch 66 finished 	ANN training loss 3.108367
# >> Epoch 67 finished 	ANN training loss 3.107275
# >> Epoch 68 finished 	ANN training loss 3.105965
# >> Epoch 69 finished 	ANN training loss 3.104479
# >> Epoch 70 finished 	ANN training loss 3.103277
# >> Epoch 71 finished 	ANN training loss 3.102437
# >> Epoch 72 finished 	ANN training loss 3.100580
# >> Epoch 73 finished 	ANN training loss 3.099591
# >> Epoch 74 finished 	ANN training loss 3.099083
# >> Epoch 75 finished 	ANN training loss 3.097277
# >> Epoch 76 finished 	ANN training loss 3.095932
# >> Epoch 77 finished 	ANN training loss 3.095431
# >> Epoch 78 finished 	ANN training loss 3.095172
# >> Epoch 79 finished 	ANN training loss 3.093172
# >> Epoch 80 finished 	ANN training loss 3.091694
# >> Epoch 81 finished 	ANN training loss 3.090606
# >> Epoch 82 finished 	ANN training loss 3.089620
# >> Epoch 83 finished 	ANN training loss 3.088393
# >> Epoch 84 finished 	ANN training loss 3.087455
# >> Epoch 85 finished 	ANN training loss 3.086561
# >> Epoch 86 finished 	ANN training loss 3.085754
# >> Epoch 87 finished 	ANN training loss 3.084717
# >> Epoch 88 finished 	ANN training loss 3.083928
# >> Epoch 89 finished 	ANN training loss 3.082551
# >> Epoch 90 finished 	ANN training loss 3.081954
# >> Epoch 91 finished 	ANN training loss 3.080603
# >> Epoch 92 finished 	ANN training loss 3.079797
# >> Epoch 93 finished 	ANN training loss 3.079096
# >> Epoch 94 finished 	ANN training loss 3.078994
# >> Epoch 95 finished 	ANN training loss 3.077294
# >> Epoch 96 finished 	ANN training loss 3.076499
# >> Epoch 97 finished 	ANN training loss 3.075558
# >> Epoch 98 finished 	ANN training loss 3.074606
# >> Epoch 99 finished 	ANN training loss 3.073759
# >> Epoch 100 finished 	ANN training loss 3.072752
# [END] Fine tuning step
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 2.721579
# >> Epoch 2 finished 	RBM Reconstruction error 2.709088
# >> Epoch 3 finished 	RBM Reconstruction error 2.697316
# >> Epoch 4 finished 	RBM Reconstruction error 2.685773
# >> Epoch 5 finished 	RBM Reconstruction error 2.674419
# >> Epoch 6 finished 	RBM Reconstruction error 2.663123
# >> Epoch 7 finished 	RBM Reconstruction error 2.652442
# >> Epoch 8 finished 	RBM Reconstruction error 2.641673
# >> Epoch 9 finished 	RBM Reconstruction error 2.631476
# >> Epoch 10 finished 	RBM Reconstruction error 2.621506
# >> Epoch 1 finished 	RBM Reconstruction error 5.207641
# >> Epoch 2 finished 	RBM Reconstruction error 5.119615
# >> Epoch 3 finished 	RBM Reconstruction error 5.033917
# >> Epoch 4 finished 	RBM Reconstruction error 4.952824
# >> Epoch 5 finished 	RBM Reconstruction error 4.874459
# >> Epoch 6 finished 	RBM Reconstruction error 4.798779
# >> Epoch 7 finished 	RBM Reconstruction error 4.727270
# >> Epoch 8 finished 	RBM Reconstruction error 4.657251
# >> Epoch 9 finished 	RBM Reconstruction error 4.592255
# >> Epoch 10 finished 	RBM Reconstruction error 4.529418
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 3.365214
# >> Epoch 2 finished 	ANN training loss 3.361229
# >> Epoch 3 finished 	ANN training loss 3.358131
# >> Epoch 4 finished 	ANN training loss 3.354605
# >> Epoch 5 finished 	ANN training loss 3.351939
# >> Epoch 6 finished 	ANN training loss 3.347997
# >> Epoch 7 finished 	ANN training loss 3.345293
# >> Epoch 8 finished 	ANN training loss 3.343701
# >> Epoch 9 finished 	ANN training loss 3.339923
# >> Epoch 10 finished 	ANN training loss 3.338019
# >> Epoch 11 finished 	ANN training loss 3.335451
# >> Epoch 12 finished 	ANN training loss 3.332881
# >> Epoch 13 finished 	ANN training loss 3.329913
# >> Epoch 14 finished 	ANN training loss 3.327779
# >> Epoch 15 finished 	ANN training loss 3.325304
# >> Epoch 16 finished 	ANN training loss 3.323188
# >> Epoch 17 finished 	ANN training loss 3.321644
# >> Epoch 18 finished 	ANN training loss 3.319474
# >> Epoch 19 finished 	ANN training loss 3.317170
# >> Epoch 20 finished 	ANN training loss 3.315724
# >> Epoch 21 finished 	ANN training loss 3.313961
# >> Epoch 22 finished 	ANN training loss 3.312078
# >> Epoch 23 finished 	ANN training loss 3.310533
# >> Epoch 24 finished 	ANN training loss 3.308475
# >> Epoch 25 finished 	ANN training loss 3.307004
# >> Epoch 26 finished 	ANN training loss 3.306727
# >> Epoch 27 finished 	ANN training loss 3.303733
# >> Epoch 28 finished 	ANN training loss 3.303147
# >> Epoch 29 finished 	ANN training loss 3.302104
# >> Epoch 30 finished 	ANN training loss 3.301017
# >> Epoch 31 finished 	ANN training loss 3.298871
# >> Epoch 32 finished 	ANN training loss 3.296807
# >> Epoch 33 finished 	ANN training loss 3.295313
# >> Epoch 34 finished 	ANN training loss 3.294503
# >> Epoch 35 finished 	ANN training loss 3.293213
# >> Epoch 36 finished 	ANN training loss 3.291691
# >> Epoch 37 finished 	ANN training loss 3.290342
# >> Epoch 38 finished 	ANN training loss 3.289984
# >> Epoch 39 finished 	ANN training loss 3.288640
# >> Epoch 40 finished 	ANN training loss 3.287574
# >> Epoch 41 finished 	ANN training loss 3.286133
# >> Epoch 42 finished 	ANN training loss 3.284428
# >> Epoch 43 finished 	ANN training loss 3.284862
# >> Epoch 44 finished 	ANN training loss 3.282715
# >> Epoch 45 finished 	ANN training loss 3.281232
# >> Epoch 46 finished 	ANN training loss 3.280377
# >> Epoch 47 finished 	ANN training loss 3.279810
# >> Epoch 48 finished 	ANN training loss 3.278381
# >> Epoch 49 finished 	ANN training loss 3.277191
# >> Epoch 50 finished 	ANN training loss 3.276454
# >> Epoch 51 finished 	ANN training loss 3.275632
# >> Epoch 52 finished 	ANN training loss 3.274356
# >> Epoch 53 finished 	ANN training loss 3.273514
# >> Epoch 54 finished 	ANN training loss 3.272367
# >> Epoch 55 finished 	ANN training loss 3.270920
# >> Epoch 56 finished 	ANN training loss 3.270007
# >> Epoch 57 finished 	ANN training loss 3.269041
# >> Epoch 58 finished 	ANN training loss 3.268324
# >> Epoch 59 finished 	ANN training loss 3.267091
# >> Epoch 60 finished 	ANN training loss 3.266276
# >> Epoch 61 finished 	ANN training loss 3.265227
# >> Epoch 62 finished 	ANN training loss 3.264733
# >> Epoch 63 finished 	ANN training loss 3.263248
# >> Epoch 64 finished 	ANN training loss 3.262211
# >> Epoch 65 finished 	ANN training loss 3.261919
# >> Epoch 66 finished 	ANN training loss 3.260649
# >> Epoch 67 finished 	ANN training loss 3.259609
# >> Epoch 68 finished 	ANN training loss 3.258856
# >> Epoch 69 finished 	ANN training loss 3.257404
# >> Epoch 70 finished 	ANN training loss 3.256753
# >> Epoch 71 finished 	ANN training loss 3.255989
# >> Epoch 72 finished 	ANN training loss 3.254973
# >> Epoch 73 finished 	ANN training loss 3.254191
# >> Epoch 74 finished 	ANN training loss 3.254104
# >> Epoch 75 finished 	ANN training loss 3.252281
# >> Epoch 76 finished 	ANN training loss 3.251239
# >> Epoch 77 finished 	ANN training loss 3.250689
# >> Epoch 78 finished 	ANN training loss 3.249466
# >> Epoch 79 finished 	ANN training loss 3.248968
# >> Epoch 80 finished 	ANN training loss 3.247381
# >> Epoch 81 finished 	ANN training loss 3.246945
# >> Epoch 82 finished 	ANN training loss 3.245859
# >> Epoch 83 finished 	ANN training loss 3.245124
# >> Epoch 84 finished 	ANN training loss 3.244818
# >> Epoch 85 finished 	ANN training loss 3.243093
# >> Epoch 86 finished 	ANN training loss 3.242639
# >> Epoch 87 finished 	ANN training loss 3.241378
# >> Epoch 88 finished 	ANN training loss 3.240295
# >> Epoch 89 finished 	ANN training loss 3.240860
# >> Epoch 90 finished 	ANN training loss 3.238599
# >> Epoch 91 finished 	ANN training loss 3.239435
# >> Epoch 92 finished 	ANN training loss 3.238134
# >> Epoch 93 finished 	ANN training loss 3.236242
# >> Epoch 94 finished 	ANN training loss 3.235322
# >> Epoch 95 finished 	ANN training loss 3.235348
# >> Epoch 96 finished 	ANN training loss 3.233729
# >> Epoch 97 finished 	ANN training loss 3.233393
# >> Epoch 98 finished 	ANN training loss 3.231956
# >> Epoch 99 finished 	ANN training loss 3.231420
# >> Epoch 100 finished 	ANN training loss 3.230835
# [END] Fine tuning step
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 3.960614
# >> Epoch 2 finished 	RBM Reconstruction error 3.940975
# >> Epoch 3 finished 	RBM Reconstruction error 3.921123
# >> Epoch 4 finished 	RBM Reconstruction error 3.901107
# >> Epoch 5 finished 	RBM Reconstruction error 3.881027
# >> Epoch 6 finished 	RBM Reconstruction error 3.861360
# >> Epoch 7 finished 	RBM Reconstruction error 3.841143
# >> Epoch 8 finished 	RBM Reconstruction error 3.820584
# >> Epoch 9 finished 	RBM Reconstruction error 3.799948
# >> Epoch 10 finished 	RBM Reconstruction error 3.779199
# >> Epoch 1 finished 	RBM Reconstruction error 6.047510
# >> Epoch 2 finished 	RBM Reconstruction error 5.952730
# >> Epoch 3 finished 	RBM Reconstruction error 5.862866
# >> Epoch 4 finished 	RBM Reconstruction error 5.776767
# >> Epoch 5 finished 	RBM Reconstruction error 5.695068
# >> Epoch 6 finished 	RBM Reconstruction error 5.615865
# >> Epoch 7 finished 	RBM Reconstruction error 5.540650
# >> Epoch 8 finished 	RBM Reconstruction error 5.467642
# >> Epoch 9 finished 	RBM Reconstruction error 5.397254
# >> Epoch 10 finished 	RBM Reconstruction error 5.329976
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 3.587703
# >> Epoch 2 finished 	ANN training loss 3.574173
# >> Epoch 3 finished 	ANN training loss 3.559185
# >> Epoch 4 finished 	ANN training loss 3.545093
# >> Epoch 5 finished 	ANN training loss 3.531331
# >> Epoch 6 finished 	ANN training loss 3.518282
# >> Epoch 7 finished 	ANN training loss 3.505886
# >> Epoch 8 finished 	ANN training loss 3.493679
# >> Epoch 9 finished 	ANN training loss 3.481790
# >> Epoch 10 finished 	ANN training loss 3.469700
# >> Epoch 11 finished 	ANN training loss 3.458576
# >> Epoch 12 finished 	ANN training loss 3.446884
# >> Epoch 13 finished 	ANN training loss 3.436450
# >> Epoch 14 finished 	ANN training loss 3.426194
# >> Epoch 15 finished 	ANN training loss 3.415652
# >> Epoch 16 finished 	ANN training loss 3.405837
# >> Epoch 17 finished 	ANN training loss 3.396013
# >> Epoch 18 finished 	ANN training loss 3.387123
# >> Epoch 19 finished 	ANN training loss 3.378273
# >> Epoch 20 finished 	ANN training loss 3.369273
# >> Epoch 21 finished 	ANN training loss 3.361223
# >> Epoch 22 finished 	ANN training loss 3.353538
# >> Epoch 23 finished 	ANN training loss 3.344940
# >> Epoch 24 finished 	ANN training loss 3.337427
# >> Epoch 25 finished 	ANN training loss 3.329722
# >> Epoch 26 finished 	ANN training loss 3.322942
# >> Epoch 27 finished 	ANN training loss 3.315284
# >> Epoch 28 finished 	ANN training loss 3.308753
# >> Epoch 29 finished 	ANN training loss 3.302874
# >> Epoch 30 finished 	ANN training loss 3.296233
# >> Epoch 31 finished 	ANN training loss 3.289468
# >> Epoch 32 finished 	ANN training loss 3.283508
# >> Epoch 33 finished 	ANN training loss 3.278532
# >> Epoch 34 finished 	ANN training loss 3.271781
# >> Epoch 35 finished 	ANN training loss 3.266687
# >> Epoch 36 finished 	ANN training loss 3.261411
# >> Epoch 37 finished 	ANN training loss 3.256974
# >> Epoch 38 finished 	ANN training loss 3.251825
# >> Epoch 39 finished 	ANN training loss 3.247044
# >> Epoch 40 finished 	ANN training loss 3.242188
# >> Epoch 41 finished 	ANN training loss 3.238811
# >> Epoch 42 finished 	ANN training loss 3.233397
# >> Epoch 43 finished 	ANN training loss 3.229673
# >> Epoch 44 finished 	ANN training loss 3.224751
# >> Epoch 45 finished 	ANN training loss 3.221430
# >> Epoch 46 finished 	ANN training loss 3.217217
# >> Epoch 47 finished 	ANN training loss 3.213768
# >> Epoch 48 finished 	ANN training loss 3.209934
# >> Epoch 49 finished 	ANN training loss 3.207017
# >> Epoch 50 finished 	ANN training loss 3.203636
# >> Epoch 51 finished 	ANN training loss 3.199600
# >> Epoch 52 finished 	ANN training loss 3.196582
# >> Epoch 53 finished 	ANN training loss 3.193871
# >> Epoch 54 finished 	ANN training loss 3.191285
# >> Epoch 55 finished 	ANN training loss 3.189264
# >> Epoch 56 finished 	ANN training loss 3.186103
# >> Epoch 57 finished 	ANN training loss 3.181965
# >> Epoch 58 finished 	ANN training loss 3.179573
# >> Epoch 59 finished 	ANN training loss 3.176600
# >> Epoch 60 finished 	ANN training loss 3.174345
# >> Epoch 61 finished 	ANN training loss 3.172595
# >> Epoch 62 finished 	ANN training loss 3.170223
# >> Epoch 63 finished 	ANN training loss 3.167436
# >> Epoch 64 finished 	ANN training loss 3.164821
# >> Epoch 65 finished 	ANN training loss 3.162511
# >> Epoch 66 finished 	ANN training loss 3.160456
# >> Epoch 67 finished 	ANN training loss 3.158826
# >> Epoch 68 finished 	ANN training loss 3.156213
# >> Epoch 69 finished 	ANN training loss 3.155180
# >> Epoch 70 finished 	ANN training loss 3.153491
# >> Epoch 71 finished 	ANN training loss 3.150620
# >> Epoch 72 finished 	ANN training loss 3.148743
# >> Epoch 73 finished 	ANN training loss 3.147146
# >> Epoch 74 finished 	ANN training loss 3.145610
# >> Epoch 75 finished 	ANN training loss 3.144421
# >> Epoch 76 finished 	ANN training loss 3.141773
# >> Epoch 77 finished 	ANN training loss 3.140042
# >> Epoch 78 finished 	ANN training loss 3.138056
# >> Epoch 79 finished 	ANN training loss 3.137353
# >> Epoch 80 finished 	ANN training loss 3.135107
# >> Epoch 81 finished 	ANN training loss 3.133562
# >> Epoch 82 finished 	ANN training loss 3.133018
# >> Epoch 83 finished 	ANN training loss 3.130228
# >> Epoch 84 finished 	ANN training loss 3.129062
# >> Epoch 85 finished 	ANN training loss 3.127267
# >> Epoch 86 finished 	ANN training loss 3.126020
# >> Epoch 87 finished 	ANN training loss 3.126007
# >> Epoch 88 finished 	ANN training loss 3.123505
# >> Epoch 89 finished 	ANN training loss 3.122038
# >> Epoch 90 finished 	ANN training loss 3.120395
# >> Epoch 91 finished 	ANN training loss 3.118870
# >> Epoch 92 finished 	ANN training loss 3.118545
# >> Epoch 93 finished 	ANN training loss 3.116264
# >> Epoch 94 finished 	ANN training loss 3.115588
# >> Epoch 95 finished 	ANN training loss 3.113598
# >> Epoch 96 finished 	ANN training loss 3.112833
# >> Epoch 97 finished 	ANN training loss 3.111666
# >> Epoch 98 finished 	ANN training loss 3.110145
# >> Epoch 99 finished 	ANN training loss 3.109000
# >> Epoch 100 finished 	ANN training loss 3.107499
# [END] Fine tuning step
# array([0.66666667, 0.41666667, 0.70833333, 0.375     , 0.66666667])
