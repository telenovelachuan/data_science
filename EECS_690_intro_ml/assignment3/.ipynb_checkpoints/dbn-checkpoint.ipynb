# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics.classification import accuracy_score
from dbn import SupervisedDBNClassification

# %%
df, target = load_iris(return_X_y=True)
df = pd.DataFrame(df, columns=["sepal length (cm)","sepal width (cm)","petal length (cm)","petal width (cm)"])
df["label"] = target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      label
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2
#
# [150 rows x 5 columns]

# %%
# Normalize
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X = df.drop(columns=["label"])
Y = df["label"]
X = ss.fit_transform(X)

# %%
#x, y = load_iris(return_X_y=True)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=1/3, random_state=0)


def evaluate_model(model_func, model_name, x_train=X_train, x_test=X_test, y_train=Y_train, y_test=Y_test):
    #gnb = GaussianNB()
    model = model_func()
    y_pred1 = model.fit(x_train, y_train).predict(x_test)

    x_train, x_test = x_test, x_train
    y_train, y_test = y_test, y_train
    #gnb = GaussianNB()
    model = model_func()
    y_pred2 = model.fit(x_train, y_train).predict(x_test)

    y_pred = np.round(np.append(y_pred2, y_pred1))
    y_true = np.append(y_test, y_train)
    print(f"Evaluating {model_name} model")
    print(f"Accuracy: {round((y_pred == y_true).sum() / len(y), 4)}")
    print(f"Confusion Matrix:\n {confusion_matrix(y_true, y_pred, labels=[0, 1, 2])}")

# %%
dbn_clf = SupervisedDBNClassification(hidden_layers_structure=[256, 256], verbose=False,
    learning_rate_rbm=0.05,
    learning_rate=0.1,
    n_epochs_rbm=10,
    n_iter_backprop=100,
    batch_size=32,
    activation_function='relu',
    dropout_p=0.2)

#     dbn_clf.fit(x_train, y_train)
#     y_pred = dbn_clf.predict(x_test)
#     print('Done.\nAccuracy: %f' % accuracy_score(y_test, y_pred))

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(dbn_clf, X, Y, cv=5)
scores
# Out:
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 2.919488
# >> Epoch 2 finished 	RBM Reconstruction error 2.903953
# >> Epoch 3 finished 	RBM Reconstruction error 2.889136
# >> Epoch 4 finished 	RBM Reconstruction error 2.875015
# >> Epoch 5 finished 	RBM Reconstruction error 2.861409
# >> Epoch 6 finished 	RBM Reconstruction error 2.848558
# >> Epoch 7 finished 	RBM Reconstruction error 2.836048
# >> Epoch 8 finished 	RBM Reconstruction error 2.824016
# >> Epoch 9 finished 	RBM Reconstruction error 2.812758
# >> Epoch 10 finished 	RBM Reconstruction error 2.801930
# >> Epoch 1 finished 	RBM Reconstruction error 5.575454
# >> Epoch 2 finished 	RBM Reconstruction error 5.454917
# >> Epoch 3 finished 	RBM Reconstruction error 5.338709
# >> Epoch 4 finished 	RBM Reconstruction error 5.229578
# >> Epoch 5 finished 	RBM Reconstruction error 5.122687
# >> Epoch 6 finished 	RBM Reconstruction error 5.024017
# >> Epoch 7 finished 	RBM Reconstruction error 4.927723
# >> Epoch 8 finished 	RBM Reconstruction error 4.836116
# >> Epoch 9 finished 	RBM Reconstruction error 4.750296
# >> Epoch 10 finished 	RBM Reconstruction error 4.667809
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 3.392269
# >> Epoch 2 finished 	ANN training loss 3.391230
# >> Epoch 3 finished 	ANN training loss 3.389444
# >> Epoch 4 finished 	ANN training loss 3.388412
# >> Epoch 5 finished 	ANN training loss 3.386681
# >> Epoch 6 finished 	ANN training loss 3.385135
# >> Epoch 7 finished 	ANN training loss 3.383393
# >> Epoch 8 finished 	ANN training loss 3.382544
# >> Epoch 9 finished 	ANN training loss 3.380968
# >> Epoch 10 finished 	ANN training loss 3.379800
# >> Epoch 11 finished 	ANN training loss 3.378235
# >> Epoch 12 finished 	ANN training loss 3.376554
# >> Epoch 13 finished 	ANN training loss 3.375969
# >> Epoch 14 finished 	ANN training loss 3.375040
# >> Epoch 15 finished 	ANN training loss 3.372394
# >> Epoch 16 finished 	ANN training loss 3.370900
# >> Epoch 17 finished 	ANN training loss 3.370044
# >> Epoch 18 finished 	ANN training loss 3.368224
# >> Epoch 19 finished 	ANN training loss 3.366409
# >> Epoch 20 finished 	ANN training loss 3.365360
# >> Epoch 21 finished 	ANN training loss 3.364796
# >> Epoch 22 finished 	ANN training loss 3.363242
# >> Epoch 23 finished 	ANN training loss 3.362427
# >> Epoch 24 finished 	ANN training loss 3.360123
# >> Epoch 25 finished 	ANN training loss 3.358243
# >> Epoch 26 finished 	ANN training loss 3.357113
# >> Epoch 27 finished 	ANN training loss 3.356667
# >> Epoch 28 finished 	ANN training loss 3.354886
# >> Epoch 29 finished 	ANN training loss 3.353504
# >> Epoch 30 finished 	ANN training loss 3.352258
# >> Epoch 31 finished 	ANN training loss 3.350589
# >> Epoch 32 finished 	ANN training loss 3.349218
# >> Epoch 33 finished 	ANN training loss 3.347754
# >> Epoch 34 finished 	ANN training loss 3.346856
# >> Epoch 35 finished 	ANN training loss 3.345707
# >> Epoch 36 finished 	ANN training loss 3.344354
# >> Epoch 37 finished 	ANN training loss 3.342793
# >> Epoch 38 finished 	ANN training loss 3.341734
# >> Epoch 39 finished 	ANN training loss 3.340598
# >> Epoch 40 finished 	ANN training loss 3.338986
# >> Epoch 41 finished 	ANN training loss 3.337743
# >> Epoch 42 finished 	ANN training loss 3.336687
# >> Epoch 43 finished 	ANN training loss 3.335473
# >> Epoch 44 finished 	ANN training loss 3.334170
# >> Epoch 45 finished 	ANN training loss 3.333352
# >> Epoch 46 finished 	ANN training loss 3.331648
# >> Epoch 47 finished 	ANN training loss 3.330907
# >> Epoch 48 finished 	ANN training loss 3.329990
# >> Epoch 49 finished 	ANN training loss 3.327872
# >> Epoch 50 finished 	ANN training loss 3.326075
# >> Epoch 51 finished 	ANN training loss 3.325662
# >> Epoch 52 finished 	ANN training loss 3.324290
# >> Epoch 53 finished 	ANN training loss 3.322463
# >> Epoch 54 finished 	ANN training loss 3.321901
# >> Epoch 55 finished 	ANN training loss 3.319940
# >> Epoch 56 finished 	ANN training loss 3.318700
# >> Epoch 57 finished 	ANN training loss 3.317315
# >> Epoch 58 finished 	ANN training loss 3.316521
# >> Epoch 59 finished 	ANN training loss 3.314695
# >> Epoch 60 finished 	ANN training loss 3.314213
# >> Epoch 61 finished 	ANN training loss 3.312963
# >> Epoch 62 finished 	ANN training loss 3.311375
# >> Epoch 63 finished 	ANN training loss 3.310246
# >> Epoch 64 finished 	ANN training loss 3.308904
# >> Epoch 65 finished 	ANN training loss 3.307789
# >> Epoch 66 finished 	ANN training loss 3.306557
# >> Epoch 67 finished 	ANN training loss 3.305057
# >> Epoch 68 finished 	ANN training loss 3.304248
# >> Epoch 69 finished 	ANN training loss 3.302579
# >> Epoch 70 finished 	ANN training loss 3.301738
# >> Epoch 71 finished 	ANN training loss 3.300129
# >> Epoch 72 finished 	ANN training loss 3.299132
# >> Epoch 73 finished 	ANN training loss 3.297392
# >> Epoch 74 finished 	ANN training loss 3.296322
# >> Epoch 75 finished 	ANN training loss 3.295479
# >> Epoch 76 finished 	ANN training loss 3.294823
# >> Epoch 77 finished 	ANN training loss 3.293542
# >> Epoch 78 finished 	ANN training loss 3.291482
# >> Epoch 79 finished 	ANN training loss 3.290996
# >> Epoch 80 finished 	ANN training loss 3.288929
# >> Epoch 81 finished 	ANN training loss 3.288274
# >> Epoch 82 finished 	ANN training loss 3.287052
# >> Epoch 83 finished 	ANN training loss 3.285543
# >> Epoch 84 finished 	ANN training loss 3.284025
# >> Epoch 85 finished 	ANN training loss 3.282629
# >> Epoch 86 finished 	ANN training loss 3.282573
# >> Epoch 87 finished 	ANN training loss 3.280805
# >> Epoch 88 finished 	ANN training loss 3.279732
# >> Epoch 89 finished 	ANN training loss 3.278213
# >> Epoch 90 finished 	ANN training loss 3.277136
# >> Epoch 91 finished 	ANN training loss 3.275633
# >> Epoch 92 finished 	ANN training loss 3.274179
# >> Epoch 93 finished 	ANN training loss 3.273971
# >> Epoch 94 finished 	ANN training loss 3.273132
# >> Epoch 95 finished 	ANN training loss 3.271329
# >> Epoch 96 finished 	ANN training loss 3.270359
# >> Epoch 97 finished 	ANN training loss 3.268758
# >> Epoch 98 finished 	ANN training loss 3.267094
# >> Epoch 99 finished 	ANN training loss 3.266258
# >> Epoch 100 finished 	ANN training loss 3.264730
# [END] Fine tuning step
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 2.265729
# >> Epoch 2 finished 	RBM Reconstruction error 2.261268
# >> Epoch 3 finished 	RBM Reconstruction error 2.257176
# >> Epoch 4 finished 	RBM Reconstruction error 2.253378
# >> Epoch 5 finished 	RBM Reconstruction error 2.249730
# >> Epoch 6 finished 	RBM Reconstruction error 2.246275
# >> Epoch 7 finished 	RBM Reconstruction error 2.242964
# >> Epoch 8 finished 	RBM Reconstruction error 2.240023
# >> Epoch 9 finished 	RBM Reconstruction error 2.237396
# >> Epoch 10 finished 	RBM Reconstruction error 2.234952
# >> Epoch 1 finished 	RBM Reconstruction error 5.497498
# >> Epoch 2 finished 	RBM Reconstruction error 5.379688
# >> Epoch 3 finished 	RBM Reconstruction error 5.268158
# >> Epoch 4 finished 	RBM Reconstruction error 5.164262
# >> Epoch 5 finished 	RBM Reconstruction error 5.065704
# >> Epoch 6 finished 	RBM Reconstruction error 4.972785
# >> Epoch 7 finished 	RBM Reconstruction error 4.885679
# >> Epoch 8 finished 	RBM Reconstruction error 4.801589
# >> Epoch 9 finished 	RBM Reconstruction error 4.722312
# >> Epoch 10 finished 	RBM Reconstruction error 4.648356
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 4.197433
# >> Epoch 2 finished 	ANN training loss 4.128752
# >> Epoch 3 finished 	ANN training loss 4.064566
# >> Epoch 4 finished 	ANN training loss 4.005472
# >> Epoch 5 finished 	ANN training loss 3.950576
# >> Epoch 6 finished 	ANN training loss 3.898701
# >> Epoch 7 finished 	ANN training loss 3.851297
# >> Epoch 8 finished 	ANN training loss 3.806976
# >> Epoch 9 finished 	ANN training loss 3.766255
# >> Epoch 10 finished 	ANN training loss 3.728485
# >> Epoch 11 finished 	ANN training loss 3.693341
# >> Epoch 12 finished 	ANN training loss 3.661236
# >> Epoch 13 finished 	ANN training loss 3.631245
# >> Epoch 14 finished 	ANN training loss 3.603754
# >> Epoch 15 finished 	ANN training loss 3.577990
# >> Epoch 16 finished 	ANN training loss 3.554687
# >> Epoch 17 finished 	ANN training loss 3.533521
# >> Epoch 18 finished 	ANN training loss 3.513457
# >> Epoch 19 finished 	ANN training loss 3.495794
# >> Epoch 20 finished 	ANN training loss 3.478717
# >> Epoch 21 finished 	ANN training loss 3.461586
# >> Epoch 22 finished 	ANN training loss 3.447336
# >> Epoch 23 finished 	ANN training loss 3.433006
# >> Epoch 24 finished 	ANN training loss 3.420677
# >> Epoch 25 finished 	ANN training loss 3.408855
# >> Epoch 26 finished 	ANN training loss 3.398360
# >> Epoch 27 finished 	ANN training loss 3.387855
# >> Epoch 28 finished 	ANN training loss 3.378820
# >> Epoch 29 finished 	ANN training loss 3.370360
# >> Epoch 30 finished 	ANN training loss 3.361592
# >> Epoch 31 finished 	ANN training loss 3.354377
# >> Epoch 32 finished 	ANN training loss 3.347100
# >> Epoch 33 finished 	ANN training loss 3.340649
# >> Epoch 34 finished 	ANN training loss 3.334984
# >> Epoch 35 finished 	ANN training loss 3.328868
# >> Epoch 36 finished 	ANN training loss 3.323451
# >> Epoch 37 finished 	ANN training loss 3.318757
# >> Epoch 38 finished 	ANN training loss 3.313750
# >> Epoch 39 finished 	ANN training loss 3.309637
# >> Epoch 40 finished 	ANN training loss 3.305417
# >> Epoch 41 finished 	ANN training loss 3.302211
# >> Epoch 42 finished 	ANN training loss 3.297961
# >> Epoch 43 finished 	ANN training loss 3.294652
# >> Epoch 44 finished 	ANN training loss 3.290574
# >> Epoch 45 finished 	ANN training loss 3.287585
# >> Epoch 46 finished 	ANN training loss 3.284687
# >> Epoch 47 finished 	ANN training loss 3.281599
# >> Epoch 48 finished 	ANN training loss 3.279065
# >> Epoch 49 finished 	ANN training loss 3.276895
# >> Epoch 50 finished 	ANN training loss 3.274609
# >> Epoch 51 finished 	ANN training loss 3.271561
# >> Epoch 52 finished 	ANN training loss 3.269715
# >> Epoch 53 finished 	ANN training loss 3.267516
# >> Epoch 54 finished 	ANN training loss 3.265590
# >> Epoch 55 finished 	ANN training loss 3.263523
# >> Epoch 56 finished 	ANN training loss 3.261460
# >> Epoch 57 finished 	ANN training loss 3.259724
# >> Epoch 58 finished 	ANN training loss 3.257485
# >> Epoch 59 finished 	ANN training loss 3.256255
# >> Epoch 60 finished 	ANN training loss 3.255063
# >> Epoch 61 finished 	ANN training loss 3.252523
# >> Epoch 62 finished 	ANN training loss 3.251113
# >> Epoch 63 finished 	ANN training loss 3.249352
# >> Epoch 64 finished 	ANN training loss 3.247854
# >> Epoch 65 finished 	ANN training loss 3.248517
# >> Epoch 66 finished 	ANN training loss 3.244959
# >> Epoch 67 finished 	ANN training loss 3.243813
# >> Epoch 68 finished 	ANN training loss 3.242222
# >> Epoch 69 finished 	ANN training loss 3.240450
# >> Epoch 70 finished 	ANN training loss 3.239679
# >> Epoch 71 finished 	ANN training loss 3.237907
# >> Epoch 72 finished 	ANN training loss 3.237017
# >> Epoch 73 finished 	ANN training loss 3.235396
# >> Epoch 74 finished 	ANN training loss 3.234284
# >> Epoch 75 finished 	ANN training loss 3.233138
# >> Epoch 76 finished 	ANN training loss 3.231389
# >> Epoch 77 finished 	ANN training loss 3.230548
# >> Epoch 78 finished 	ANN training loss 3.228984
# >> Epoch 79 finished 	ANN training loss 3.228889
# >> Epoch 80 finished 	ANN training loss 3.227465
# >> Epoch 81 finished 	ANN training loss 3.225970
# >> Epoch 82 finished 	ANN training loss 3.224085
# >> Epoch 83 finished 	ANN training loss 3.224157
# >> Epoch 84 finished 	ANN training loss 3.222043
# >> Epoch 85 finished 	ANN training loss 3.222037
# >> Epoch 86 finished 	ANN training loss 3.220010
# >> Epoch 87 finished 	ANN training loss 3.219156
# >> Epoch 88 finished 	ANN training loss 3.217610
# >> Epoch 89 finished 	ANN training loss 3.216503
# >> Epoch 90 finished 	ANN training loss 3.215422
# >> Epoch 91 finished 	ANN training loss 3.214145
# >> Epoch 92 finished 	ANN training loss 3.213377
# >> Epoch 93 finished 	ANN training loss 3.211944
# >> Epoch 94 finished 	ANN training loss 3.211253
# >> Epoch 95 finished 	ANN training loss 3.210200
# >> Epoch 96 finished 	ANN training loss 3.209510
# >> Epoch 97 finished 	ANN training loss 3.208290
# >> Epoch 98 finished 	ANN training loss 3.206170
# >> Epoch 99 finished 	ANN training loss 3.206045
# >> Epoch 100 finished 	ANN training loss 3.204489
# [END] Fine tuning step
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 3.300285
# >> Epoch 2 finished 	RBM Reconstruction error 3.277645
# >> Epoch 3 finished 	RBM Reconstruction error 3.255940
# >> Epoch 4 finished 	RBM Reconstruction error 3.234188
# >> Epoch 5 finished 	RBM Reconstruction error 3.213612
# >> Epoch 6 finished 	RBM Reconstruction error 3.193664
# >> Epoch 7 finished 	RBM Reconstruction error 3.174321
# >> Epoch 8 finished 	RBM Reconstruction error 3.154238
# >> Epoch 9 finished 	RBM Reconstruction error 3.135837
# >> Epoch 10 finished 	RBM Reconstruction error 3.117441
# >> Epoch 1 finished 	RBM Reconstruction error 5.228543
# >> Epoch 2 finished 	RBM Reconstruction error 5.139915
# >> Epoch 3 finished 	RBM Reconstruction error 5.057194
# >> Epoch 4 finished 	RBM Reconstruction error 4.975231
# >> Epoch 5 finished 	RBM Reconstruction error 4.897122
# >> Epoch 6 finished 	RBM Reconstruction error 4.822305
# >> Epoch 7 finished 	RBM Reconstruction error 4.751822
# >> Epoch 8 finished 	RBM Reconstruction error 4.685366
# >> Epoch 9 finished 	RBM Reconstruction error 4.621231
# >> Epoch 10 finished 	RBM Reconstruction error 4.558630
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 3.134581
# >> Epoch 2 finished 	ANN training loss 3.131261
# >> Epoch 3 finished 	ANN training loss 3.128348
# >> Epoch 4 finished 	ANN training loss 3.125867
# >> Epoch 5 finished 	ANN training loss 3.123441
# >> Epoch 6 finished 	ANN training loss 3.121135
# >> Epoch 7 finished 	ANN training loss 3.118995
# >> Epoch 8 finished 	ANN training loss 3.116468
# >> Epoch 9 finished 	ANN training loss 3.114429
# >> Epoch 10 finished 	ANN training loss 3.112382
# >> Epoch 11 finished 	ANN training loss 3.110077
# >> Epoch 12 finished 	ANN training loss 3.108507
# >> Epoch 13 finished 	ANN training loss 3.106654
# >> Epoch 14 finished 	ANN training loss 3.105282
# >> Epoch 15 finished 	ANN training loss 3.102853
# >> Epoch 16 finished 	ANN training loss 3.100579
# >> Epoch 17 finished 	ANN training loss 3.099207
# >> Epoch 18 finished 	ANN training loss 3.097295
# >> Epoch 19 finished 	ANN training loss 3.095866
# >> Epoch 20 finished 	ANN training loss 3.094052
# >> Epoch 21 finished 	ANN training loss 3.092473
# >> Epoch 22 finished 	ANN training loss 3.091461
# >> Epoch 23 finished 	ANN training loss 3.089546
# >> Epoch 24 finished 	ANN training loss 3.087731
# >> Epoch 25 finished 	ANN training loss 3.087185
# >> Epoch 26 finished 	ANN training loss 3.085006
# >> Epoch 27 finished 	ANN training loss 3.084210
# >> Epoch 28 finished 	ANN training loss 3.082342
# >> Epoch 29 finished 	ANN training loss 3.081093
# >> Epoch 30 finished 	ANN training loss 3.079698
# >> Epoch 31 finished 	ANN training loss 3.078169
# >> Epoch 32 finished 	ANN training loss 3.077237
# >> Epoch 33 finished 	ANN training loss 3.075457
# >> Epoch 34 finished 	ANN training loss 3.074148
# >> Epoch 35 finished 	ANN training loss 3.073833
# >> Epoch 36 finished 	ANN training loss 3.071860
# >> Epoch 37 finished 	ANN training loss 3.070434
# >> Epoch 38 finished 	ANN training loss 3.069856
# >> Epoch 39 finished 	ANN training loss 3.068130
# >> Epoch 40 finished 	ANN training loss 3.066890
# >> Epoch 41 finished 	ANN training loss 3.065451
# >> Epoch 42 finished 	ANN training loss 3.064416
# >> Epoch 43 finished 	ANN training loss 3.063316
# >> Epoch 44 finished 	ANN training loss 3.062221
# >> Epoch 45 finished 	ANN training loss 3.060925
# >> Epoch 46 finished 	ANN training loss 3.060104
# >> Epoch 47 finished 	ANN training loss 3.058574
# >> Epoch 48 finished 	ANN training loss 3.057520
# >> Epoch 49 finished 	ANN training loss 3.056347
# >> Epoch 50 finished 	ANN training loss 3.055367
# >> Epoch 51 finished 	ANN training loss 3.054334
# >> Epoch 52 finished 	ANN training loss 3.053168
# >> Epoch 53 finished 	ANN training loss 3.052320
# >> Epoch 54 finished 	ANN training loss 3.051088
# >> Epoch 55 finished 	ANN training loss 3.050708
# >> Epoch 56 finished 	ANN training loss 3.049330
# >> Epoch 57 finished 	ANN training loss 3.047523
# >> Epoch 58 finished 	ANN training loss 3.046228
# >> Epoch 59 finished 	ANN training loss 3.045088
# >> Epoch 60 finished 	ANN training loss 3.043964
# >> Epoch 61 finished 	ANN training loss 3.042750
# >> Epoch 62 finished 	ANN training loss 3.042523
# >> Epoch 63 finished 	ANN training loss 3.041181
# >> Epoch 64 finished 	ANN training loss 3.039978
# >> Epoch 65 finished 	ANN training loss 3.038705
# >> Epoch 66 finished 	ANN training loss 3.037192
# >> Epoch 67 finished 	ANN training loss 3.036635
# >> Epoch 68 finished 	ANN training loss 3.035247
# >> Epoch 69 finished 	ANN training loss 3.034151
# >> Epoch 70 finished 	ANN training loss 3.034191
# >> Epoch 71 finished 	ANN training loss 3.031971
# >> Epoch 72 finished 	ANN training loss 3.031657
# >> Epoch 73 finished 	ANN training loss 3.030221
# >> Epoch 74 finished 	ANN training loss 3.028881
# >> Epoch 75 finished 	ANN training loss 3.028382
# >> Epoch 76 finished 	ANN training loss 3.026634
# >> Epoch 77 finished 	ANN training loss 3.026348
# >> Epoch 78 finished 	ANN training loss 3.024853
# >> Epoch 79 finished 	ANN training loss 3.023877
# >> Epoch 80 finished 	ANN training loss 3.022533
# >> Epoch 81 finished 	ANN training loss 3.021270
# >> Epoch 82 finished 	ANN training loss 3.021010
# >> Epoch 83 finished 	ANN training loss 3.019375
# >> Epoch 84 finished 	ANN training loss 3.018339
# >> Epoch 85 finished 	ANN training loss 3.017048
# >> Epoch 86 finished 	ANN training loss 3.016250
# >> Epoch 87 finished 	ANN training loss 3.015969
# >> Epoch 88 finished 	ANN training loss 3.014337
# >> Epoch 89 finished 	ANN training loss 3.013079
# >> Epoch 90 finished 	ANN training loss 3.011977
# >> Epoch 91 finished 	ANN training loss 3.010754
# >> Epoch 92 finished 	ANN training loss 3.009976
# >> Epoch 93 finished 	ANN training loss 3.008756
# >> Epoch 94 finished 	ANN training loss 3.007840
# >> Epoch 95 finished 	ANN training loss 3.007007
# >> Epoch 96 finished 	ANN training loss 3.005482
# >> Epoch 97 finished 	ANN training loss 3.004470
# >> Epoch 98 finished 	ANN training loss 3.003830
# >> Epoch 99 finished 	ANN training loss 3.002710
# >> Epoch 100 finished 	ANN training loss 3.002571
# [END] Fine tuning step
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 2.597417
# >> Epoch 2 finished 	RBM Reconstruction error 2.582892
# >> Epoch 3 finished 	RBM Reconstruction error 2.569220
# >> Epoch 4 finished 	RBM Reconstruction error 2.556107
# >> Epoch 5 finished 	RBM Reconstruction error 2.543548
# >> Epoch 6 finished 	RBM Reconstruction error 2.530992
# >> Epoch 7 finished 	RBM Reconstruction error 2.519077
# >> Epoch 8 finished 	RBM Reconstruction error 2.507912
# >> Epoch 9 finished 	RBM Reconstruction error 2.496793
# >> Epoch 10 finished 	RBM Reconstruction error 2.486367
# >> Epoch 1 finished 	RBM Reconstruction error 5.288291
# >> Epoch 2 finished 	RBM Reconstruction error 5.165305
# >> Epoch 3 finished 	RBM Reconstruction error 5.050181
# >> Epoch 4 finished 	RBM Reconstruction error 4.939748
# >> Epoch 5 finished 	RBM Reconstruction error 4.835879
# >> Epoch 6 finished 	RBM Reconstruction error 4.735400
# >> Epoch 7 finished 	RBM Reconstruction error 4.640975
# >> Epoch 8 finished 	RBM Reconstruction error 4.550997
# >> Epoch 9 finished 	RBM Reconstruction error 4.465908
# >> Epoch 10 finished 	RBM Reconstruction error 4.383830
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 3.241437
# >> Epoch 2 finished 	ANN training loss 3.235203
# >> Epoch 3 finished 	ANN training loss 3.230653
# >> Epoch 4 finished 	ANN training loss 3.225246
# >> Epoch 5 finished 	ANN training loss 3.221247
# >> Epoch 6 finished 	ANN training loss 3.216502
# >> Epoch 7 finished 	ANN training loss 3.211937
# >> Epoch 8 finished 	ANN training loss 3.208392
# >> Epoch 9 finished 	ANN training loss 3.203942
# >> Epoch 10 finished 	ANN training loss 3.200202
# >> Epoch 11 finished 	ANN training loss 3.197346
# >> Epoch 12 finished 	ANN training loss 3.193575
# >> Epoch 13 finished 	ANN training loss 3.190366
# >> Epoch 14 finished 	ANN training loss 3.187245
# >> Epoch 15 finished 	ANN training loss 3.184325
# >> Epoch 16 finished 	ANN training loss 3.181369
# >> Epoch 17 finished 	ANN training loss 3.179197
# >> Epoch 18 finished 	ANN training loss 3.176904
# >> Epoch 19 finished 	ANN training loss 3.173605
# >> Epoch 20 finished 	ANN training loss 3.171530
# >> Epoch 21 finished 	ANN training loss 3.169390
# >> Epoch 22 finished 	ANN training loss 3.167085
# >> Epoch 23 finished 	ANN training loss 3.164999
# >> Epoch 24 finished 	ANN training loss 3.163267
# >> Epoch 25 finished 	ANN training loss 3.161643
# >> Epoch 26 finished 	ANN training loss 3.159010
# >> Epoch 27 finished 	ANN training loss 3.157440
# >> Epoch 28 finished 	ANN training loss 3.155237
# >> Epoch 29 finished 	ANN training loss 3.154406
# >> Epoch 30 finished 	ANN training loss 3.153271
# >> Epoch 31 finished 	ANN training loss 3.150362
# >> Epoch 32 finished 	ANN training loss 3.149076
# >> Epoch 33 finished 	ANN training loss 3.147667
# >> Epoch 34 finished 	ANN training loss 3.146386
# >> Epoch 35 finished 	ANN training loss 3.145328
# >> Epoch 36 finished 	ANN training loss 3.143451
# >> Epoch 37 finished 	ANN training loss 3.142047
# >> Epoch 38 finished 	ANN training loss 3.140619
# >> Epoch 39 finished 	ANN training loss 3.139134
# >> Epoch 40 finished 	ANN training loss 3.138131
# >> Epoch 41 finished 	ANN training loss 3.137373
# >> Epoch 42 finished 	ANN training loss 3.135704
# >> Epoch 43 finished 	ANN training loss 3.134129
# >> Epoch 44 finished 	ANN training loss 3.133484
# >> Epoch 45 finished 	ANN training loss 3.132272
# >> Epoch 46 finished 	ANN training loss 3.130730
# >> Epoch 47 finished 	ANN training loss 3.129756
# >> Epoch 48 finished 	ANN training loss 3.128929
# >> Epoch 49 finished 	ANN training loss 3.128557
# >> Epoch 50 finished 	ANN training loss 3.126236
# >> Epoch 51 finished 	ANN training loss 3.125768
# >> Epoch 52 finished 	ANN training loss 3.124633
# >> Epoch 53 finished 	ANN training loss 3.123308
# >> Epoch 54 finished 	ANN training loss 3.122317
# >> Epoch 55 finished 	ANN training loss 3.121378
# >> Epoch 56 finished 	ANN training loss 3.120730
# >> Epoch 57 finished 	ANN training loss 3.120191
# >> Epoch 58 finished 	ANN training loss 3.118415
# >> Epoch 59 finished 	ANN training loss 3.118631
# >> Epoch 60 finished 	ANN training loss 3.117206
# >> Epoch 61 finished 	ANN training loss 3.115314
# >> Epoch 62 finished 	ANN training loss 3.114409
# >> Epoch 63 finished 	ANN training loss 3.113412
# >> Epoch 64 finished 	ANN training loss 3.113588
# >> Epoch 65 finished 	ANN training loss 3.111836
# >> Epoch 66 finished 	ANN training loss 3.111259
# >> Epoch 67 finished 	ANN training loss 3.109818
# >> Epoch 68 finished 	ANN training loss 3.109111
# >> Epoch 69 finished 	ANN training loss 3.108157
# >> Epoch 70 finished 	ANN training loss 3.107354
# >> Epoch 71 finished 	ANN training loss 3.106484
# >> Epoch 72 finished 	ANN training loss 3.105090
# >> Epoch 73 finished 	ANN training loss 3.104432
# >> Epoch 74 finished 	ANN training loss 3.105407
# >> Epoch 75 finished 	ANN training loss 3.103006
# >> Epoch 76 finished 	ANN training loss 3.102059
# >> Epoch 77 finished 	ANN training loss 3.100836
# >> Epoch 78 finished 	ANN training loss 3.100418
# >> Epoch 79 finished 	ANN training loss 3.099330
# >> Epoch 80 finished 	ANN training loss 3.098682
# >> Epoch 81 finished 	ANN training loss 3.097426
# >> Epoch 82 finished 	ANN training loss 3.096475
# >> Epoch 83 finished 	ANN training loss 3.095999
# >> Epoch 84 finished 	ANN training loss 3.095708
# >> Epoch 85 finished 	ANN training loss 3.094472
# >> Epoch 86 finished 	ANN training loss 3.092988
# >> Epoch 87 finished 	ANN training loss 3.092927
# >> Epoch 88 finished 	ANN training loss 3.091231
# >> Epoch 89 finished 	ANN training loss 3.091087
# >> Epoch 90 finished 	ANN training loss 3.090430
# >> Epoch 91 finished 	ANN training loss 3.088885
# >> Epoch 92 finished 	ANN training loss 3.088457
# >> Epoch 93 finished 	ANN training loss 3.086835
# >> Epoch 94 finished 	ANN training loss 3.086310
# >> Epoch 95 finished 	ANN training loss 3.085513
# >> Epoch 96 finished 	ANN training loss 3.084337
# >> Epoch 97 finished 	ANN training loss 3.083602
# >> Epoch 98 finished 	ANN training loss 3.082788
# >> Epoch 99 finished 	ANN training loss 3.081966
# >> Epoch 100 finished 	ANN training loss 3.081854
# [END] Fine tuning step
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 3.541284
# >> Epoch 2 finished 	RBM Reconstruction error 3.506673
# >> Epoch 3 finished 	RBM Reconstruction error 3.472987
# >> Epoch 4 finished 	RBM Reconstruction error 3.439538
# >> Epoch 5 finished 	RBM Reconstruction error 3.407884
# >> Epoch 6 finished 	RBM Reconstruction error 3.376965
# >> Epoch 7 finished 	RBM Reconstruction error 3.346624
# >> Epoch 8 finished 	RBM Reconstruction error 3.317524
# >> Epoch 9 finished 	RBM Reconstruction error 3.288370
# >> Epoch 10 finished 	RBM Reconstruction error 3.259990
# >> Epoch 1 finished 	RBM Reconstruction error 5.787933
# >> Epoch 2 finished 	RBM Reconstruction error 5.668978
# >> Epoch 3 finished 	RBM Reconstruction error 5.556010
# >> Epoch 4 finished 	RBM Reconstruction error 5.451395
# >> Epoch 5 finished 	RBM Reconstruction error 5.351200
# >> Epoch 6 finished 	RBM Reconstruction error 5.255170
# >> Epoch 7 finished 	RBM Reconstruction error 5.163921
# >> Epoch 8 finished 	RBM Reconstruction error 5.078021
# >> Epoch 9 finished 	RBM Reconstruction error 4.997530
# >> Epoch 10 finished 	RBM Reconstruction error 4.920296
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 3.487284
# >> Epoch 2 finished 	ANN training loss 3.476894
# >> Epoch 3 finished 	ANN training loss 3.469378
# >> Epoch 4 finished 	ANN training loss 3.459466
# >> Epoch 5 finished 	ANN training loss 3.451965
# >> Epoch 6 finished 	ANN training loss 3.443983
# >> Epoch 7 finished 	ANN training loss 3.437219
# >> Epoch 8 finished 	ANN training loss 3.430597
# >> Epoch 9 finished 	ANN training loss 3.424936
# >> Epoch 10 finished 	ANN training loss 3.419283
# >> Epoch 11 finished 	ANN training loss 3.414154
# >> Epoch 12 finished 	ANN training loss 3.409461
# >> Epoch 13 finished 	ANN training loss 3.404364
# >> Epoch 14 finished 	ANN training loss 3.400046
# >> Epoch 15 finished 	ANN training loss 3.395455
# >> Epoch 16 finished 	ANN training loss 3.391250
# >> Epoch 17 finished 	ANN training loss 3.387493
# >> Epoch 18 finished 	ANN training loss 3.384137
# >> Epoch 19 finished 	ANN training loss 3.380448
# >> Epoch 20 finished 	ANN training loss 3.376842
# >> Epoch 21 finished 	ANN training loss 3.373815
# >> Epoch 22 finished 	ANN training loss 3.371190
# >> Epoch 23 finished 	ANN training loss 3.368886
# >> Epoch 24 finished 	ANN training loss 3.365772
# >> Epoch 25 finished 	ANN training loss 3.362941
# >> Epoch 26 finished 	ANN training loss 3.360506
# >> Epoch 27 finished 	ANN training loss 3.359367
# >> Epoch 28 finished 	ANN training loss 3.355885
# >> Epoch 29 finished 	ANN training loss 3.352928
# >> Epoch 30 finished 	ANN training loss 3.351097
# >> Epoch 31 finished 	ANN training loss 3.349301
# >> Epoch 32 finished 	ANN training loss 3.346773
# >> Epoch 33 finished 	ANN training loss 3.344504
# >> Epoch 34 finished 	ANN training loss 3.342569
# >> Epoch 35 finished 	ANN training loss 3.341097
# >> Epoch 36 finished 	ANN training loss 3.339558
# >> Epoch 37 finished 	ANN training loss 3.338893
# >> Epoch 38 finished 	ANN training loss 3.335676
# >> Epoch 39 finished 	ANN training loss 3.333427
# >> Epoch 40 finished 	ANN training loss 3.331616
# >> Epoch 41 finished 	ANN training loss 3.331309
# >> Epoch 42 finished 	ANN training loss 3.328471
# >> Epoch 43 finished 	ANN training loss 3.327478
# >> Epoch 44 finished 	ANN training loss 3.325458
# >> Epoch 45 finished 	ANN training loss 3.323733
# >> Epoch 46 finished 	ANN training loss 3.322702
# >> Epoch 47 finished 	ANN training loss 3.320671
# >> Epoch 48 finished 	ANN training loss 3.319433
# >> Epoch 49 finished 	ANN training loss 3.318097
# >> Epoch 50 finished 	ANN training loss 3.317047
# >> Epoch 51 finished 	ANN training loss 3.314616
# >> Epoch 52 finished 	ANN training loss 3.313601
# >> Epoch 53 finished 	ANN training loss 3.312201
# >> Epoch 54 finished 	ANN training loss 3.310936
# >> Epoch 55 finished 	ANN training loss 3.309361
# >> Epoch 56 finished 	ANN training loss 3.307902
# >> Epoch 57 finished 	ANN training loss 3.308190
# >> Epoch 58 finished 	ANN training loss 3.305486
# >> Epoch 59 finished 	ANN training loss 3.304032
# >> Epoch 60 finished 	ANN training loss 3.303966
# >> Epoch 61 finished 	ANN training loss 3.300853
# >> Epoch 62 finished 	ANN training loss 3.300455
# >> Epoch 63 finished 	ANN training loss 3.298330
# >> Epoch 64 finished 	ANN training loss 3.297696
# >> Epoch 65 finished 	ANN training loss 3.295722
# >> Epoch 66 finished 	ANN training loss 3.294439
# >> Epoch 67 finished 	ANN training loss 3.293143
# >> Epoch 68 finished 	ANN training loss 3.292048
# >> Epoch 69 finished 	ANN training loss 3.290636
# >> Epoch 70 finished 	ANN training loss 3.290358
# >> Epoch 71 finished 	ANN training loss 3.288100
# >> Epoch 72 finished 	ANN training loss 3.286674
# >> Epoch 73 finished 	ANN training loss 3.286020
# >> Epoch 74 finished 	ANN training loss 3.284951
# >> Epoch 75 finished 	ANN training loss 3.282963
# >> Epoch 76 finished 	ANN training loss 3.281807
# >> Epoch 77 finished 	ANN training loss 3.281188
# >> Epoch 78 finished 	ANN training loss 3.279312
# >> Epoch 79 finished 	ANN training loss 3.278448
# >> Epoch 80 finished 	ANN training loss 3.276847
# >> Epoch 81 finished 	ANN training loss 3.275590
# >> Epoch 82 finished 	ANN training loss 3.274994
# >> Epoch 83 finished 	ANN training loss 3.273564
# >> Epoch 84 finished 	ANN training loss 3.271850
# >> Epoch 85 finished 	ANN training loss 3.270387
# >> Epoch 86 finished 	ANN training loss 3.269249
# >> Epoch 87 finished 	ANN training loss 3.269116
# >> Epoch 88 finished 	ANN training loss 3.267542
# >> Epoch 89 finished 	ANN training loss 3.265501
# >> Epoch 90 finished 	ANN training loss 3.264305
# >> Epoch 91 finished 	ANN training loss 3.263507
# >> Epoch 92 finished 	ANN training loss 3.262554
# >> Epoch 93 finished 	ANN training loss 3.260816
# >> Epoch 94 finished 	ANN training loss 3.260259
# >> Epoch 95 finished 	ANN training loss 3.258275
# >> Epoch 96 finished 	ANN training loss 3.257051
# >> Epoch 97 finished 	ANN training loss 3.256314
# >> Epoch 98 finished 	ANN training loss 3.254863
# >> Epoch 99 finished 	ANN training loss 3.253711
# >> Epoch 100 finished 	ANN training loss 3.252783
# [END] Fine tuning step
# array([0.36666667, 0.56666667, 0.86666667, 0.86666667, 0.26666667])
