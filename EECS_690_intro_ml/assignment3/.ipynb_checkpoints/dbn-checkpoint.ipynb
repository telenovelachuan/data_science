# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics.classification import accuracy_score
from dbn import SupervisedDBNClassification

# %%
df, target = load_iris(return_X_y=True)
df = pd.DataFrame(df, columns=["sepal length (cm)","sepal width (cm)","petal length (cm)","petal width (cm)"])
df["label"] = target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      label
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2
#
# [150 rows x 5 columns]

# %%
# Normalize
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X = df.drop(columns=["label"])
Y = df["label"]
X = ss.fit_transform(X)

# %%
#x, y = load_iris(return_X_y=True)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=1/3, random_state=0)


def evaluate_model(model_func, model_name, x_train=X_train, x_test=X_test, y_train=Y_train, y_test=Y_test):
    #gnb = GaussianNB()
    model = model_func()
    y_pred1 = model.fit(x_train, y_train).predict(x_test)

    x_train, x_test = x_test, x_train
    y_train, y_test = y_test, y_train
    #gnb = GaussianNB()
    model = model_func()
    y_pred2 = model.fit(x_train, y_train).predict(x_test)

    y_pred = np.round(np.append(y_pred2, y_pred1))
    y_true = np.append(y_test, y_train)
    print(f"Evaluating {model_name} model")
    print(f"Accuracy: {round((y_pred == y_true).sum() / len(y), 4)}")
    print(f"Confusion Matrix:\n {confusion_matrix(y_true, y_pred, labels=[0, 1, 2])}")

# %%
dbn_clf = SupervisedDBNClassification(hidden_layers_structure=[256, 256],
learning_rate_rbm=0.05,
learning_rate=0.1,
n_epochs_rbm=10,
n_iter_backprop=100,
batch_size=32,
activation_function='relu',
dropout_p=0.2)

dbn_clf.fit(X_train, Y_train)
Y_pred = dbn_clf.predict(X_test)
print('Done.\nAccuracy: %f' % accuracy_score(Y_test, Y_pred))
# Out:
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 2.245567
# >> Epoch 2 finished 	RBM Reconstruction error 2.229391
# >> Epoch 3 finished 	RBM Reconstruction error 2.369546
# >> Epoch 4 finished 	RBM Reconstruction error 2.612712
# >> Epoch 5 finished 	RBM Reconstruction error 3.047414
# >> Epoch 6 finished 	RBM Reconstruction error 3.942740
# >> Epoch 7 finished 	RBM Reconstruction error 7.214129
# >> Epoch 8 finished 	RBM Reconstruction error 15.138352
# >> Epoch 9 finished 	RBM Reconstruction error 22.457872
# >> Epoch 10 finished 	RBM Reconstruction error 57.427954
# >> Epoch 1 finished 	RBM Reconstruction error 322.577587
# >> Epoch 2 finished 	RBM Reconstruction error 322.152861
# >> Epoch 3 finished 	RBM Reconstruction error 3454.678569
# >> Epoch 4 finished 	RBM Reconstruction error 321.455883
# >> Epoch 5 finished 	RBM Reconstruction error 75973935.252262
# >> Epoch 6 finished 	RBM Reconstruction error 294.928458
# >> Epoch 7 finished 	RBM Reconstruction error 266.512301
# >> Epoch 8 finished 	RBM Reconstruction error 194.322033
# >> Epoch 9 finished 	RBM Reconstruction error 252.159565
# >> Epoch 10 finished 	RBM Reconstruction error 228.572093
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 3.103713
# >> Epoch 2 finished 	ANN training loss 2.217659
# >> Epoch 3 finished 	ANN training loss 2.034705
# >> Epoch 4 finished 	ANN training loss 1.775224
# >> Epoch 5 finished 	ANN training loss 1.840221
# >> Epoch 6 finished 	ANN training loss 1.633373
# >> Epoch 7 finished 	ANN training loss 1.588516
# >> Epoch 8 finished 	ANN training loss 1.566412
# >> Epoch 9 finished 	ANN training loss 1.645144
# >> Epoch 10 finished 	ANN training loss 1.492867
# >> Epoch 11 finished 	ANN training loss 1.539670
# >> Epoch 12 finished 	ANN training loss 1.431454
# >> Epoch 13 finished 	ANN training loss 1.445186
# >> Epoch 14 finished 	ANN training loss 1.408444
# >> Epoch 15 finished 	ANN training loss 1.322502
# >> Epoch 16 finished 	ANN training loss 1.324302
# >> Epoch 17 finished 	ANN training loss 1.263580
# >> Epoch 18 finished 	ANN training loss 1.253054
# >> Epoch 19 finished 	ANN training loss 1.165243
# >> Epoch 20 finished 	ANN training loss 1.250949
# >> Epoch 21 finished 	ANN training loss 1.295123
# >> Epoch 22 finished 	ANN training loss 1.129595
# >> Epoch 23 finished 	ANN training loss 1.263954
# >> Epoch 24 finished 	ANN training loss 1.077415
# >> Epoch 25 finished 	ANN training loss 1.255952
# >> Epoch 26 finished 	ANN training loss 1.181063
# >> Epoch 27 finished 	ANN training loss 1.135240
# >> Epoch 28 finished 	ANN training loss 1.158144
# >> Epoch 29 finished 	ANN training loss 1.291810
# >> Epoch 30 finished 	ANN training loss 1.168786
# >> Epoch 31 finished 	ANN training loss 1.134524
# >> Epoch 32 finished 	ANN training loss 1.107119
# >> Epoch 33 finished 	ANN training loss 1.111995
# >> Epoch 34 finished 	ANN training loss 1.090775
# >> Epoch 35 finished 	ANN training loss 1.047178
# >> Epoch 36 finished 	ANN training loss 1.012421
# >> Epoch 37 finished 	ANN training loss 1.092610
# >> Epoch 38 finished 	ANN training loss 0.933990
# >> Epoch 39 finished 	ANN training loss 0.971467
# >> Epoch 40 finished 	ANN training loss 1.072972
# >> Epoch 41 finished 	ANN training loss 1.002165
# >> Epoch 42 finished 	ANN training loss 1.060861
# >> Epoch 43 finished 	ANN training loss 0.929441
# >> Epoch 44 finished 	ANN training loss 1.037573
# >> Epoch 45 finished 	ANN training loss 0.998296
# >> Epoch 46 finished 	ANN training loss 1.054866
# >> Epoch 47 finished 	ANN training loss 1.158594
# >> Epoch 48 finished 	ANN training loss 1.194353
# >> Epoch 49 finished 	ANN training loss 0.837213
# >> Epoch 50 finished 	ANN training loss 0.943147
# >> Epoch 51 finished 	ANN training loss 1.143792
# >> Epoch 52 finished 	ANN training loss 0.937323
# >> Epoch 53 finished 	ANN training loss 1.254910
# >> Epoch 54 finished 	ANN training loss 0.908940
# >> Epoch 55 finished 	ANN training loss 1.022727
# >> Epoch 56 finished 	ANN training loss 1.015604
# >> Epoch 57 finished 	ANN training loss 0.973048
# >> Epoch 58 finished 	ANN training loss 0.966790
# >> Epoch 59 finished 	ANN training loss 0.891871
# >> Epoch 60 finished 	ANN training loss 0.909803
# >> Epoch 61 finished 	ANN training loss 1.065161
# >> Epoch 62 finished 	ANN training loss 1.085953
# >> Epoch 63 finished 	ANN training loss 0.869316
# >> Epoch 64 finished 	ANN training loss 0.863074
# >> Epoch 65 finished 	ANN training loss 1.030693
# >> Epoch 66 finished 	ANN training loss 0.918374
# >> Epoch 67 finished 	ANN training loss 0.944771
# >> Epoch 68 finished 	ANN training loss 0.850270
# >> Epoch 69 finished 	ANN training loss 0.925114
# >> Epoch 70 finished 	ANN training loss 1.045447
# >> Epoch 71 finished 	ANN training loss 1.007984
# >> Epoch 72 finished 	ANN training loss 0.855441
# >> Epoch 73 finished 	ANN training loss 0.879469
# >> Epoch 74 finished 	ANN training loss 0.911860
# >> Epoch 75 finished 	ANN training loss 0.920180
# >> Epoch 76 finished 	ANN training loss 0.853506
# >> Epoch 77 finished 	ANN training loss 0.882475
# >> Epoch 78 finished 	ANN training loss 0.828321
# >> Epoch 79 finished 	ANN training loss 0.987208
# >> Epoch 80 finished 	ANN training loss 0.935948
# >> Epoch 81 finished 	ANN training loss 1.048121
# >> Epoch 82 finished 	ANN training loss 0.981620
# >> Epoch 83 finished 	ANN training loss 0.950632
# >> Epoch 84 finished 	ANN training loss 0.993144
# >> Epoch 85 finished 	ANN training loss 0.757278
# >> Epoch 86 finished 	ANN training loss 0.802916
# >> Epoch 87 finished 	ANN training loss 0.929361
# >> Epoch 88 finished 	ANN training loss 0.907518
# >> Epoch 89 finished 	ANN training loss 0.937492
# >> Epoch 90 finished 	ANN training loss 0.984034
# >> Epoch 91 finished 	ANN training loss 0.900193
# >> Epoch 92 finished 	ANN training loss 0.791108
# >> Epoch 93 finished 	ANN training loss 1.103457
# >> Epoch 94 finished 	ANN training loss 0.876935
# >> Epoch 95 finished 	ANN training loss 0.961009
# >> Epoch 96 finished 	ANN training loss 0.890790
# >> Epoch 97 finished 	ANN training loss 0.888195
# >> Epoch 98 finished 	ANN training loss 0.922152
# >> Epoch 99 finished 	ANN training loss 0.945807
# >> Epoch 100 finished 	ANN training loss 0.689920
# [END] Fine tuning step
# Done.
# Accuracy: 0.860000
