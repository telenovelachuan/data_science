# %%
import pandas as pd
from sklearn import datasets
import math

iris, target = datasets.load_iris(as_frame=True, return_X_y=True)
iris["label"] = target
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      label
# 0        0
# ...

# %%
# setosa
setosa = iris[iris["label"]==0]
len(setosa)
# Out:
# 50

# %%
setosa["petal width (cm)"].var()
# Out:
# 0.01110612244897959

# %%
setosa["petal length (cm)"].var()
math.pow(setosa["petal width (cm)"].var(), 0.5)
# Out:
# 0.10538558938004565

# %%
versicolor = iris[iris["label"]==1]
len(versicolor)
# Out:
# 50

# %%
a = versicolor["sepal length (cm)"].var()
print(a)
print(math.pow(a, 0.5))
# Out:
# 0.2664326530612245
# 0.5161711470638634

# %%
b = versicolor["petal width (cm)"].var()
print(b)
print(math.pow(b, 0.5))
# Out:
# 0.03910612244897959
# 0.19775268000454405

# %%
virginica = iris[iris["label"]==2]
len(virginica)
# Out:
# 50

# %%
a = virginica["petal width (cm)"].var()
print(a)
print(math.pow(a, 0.5))
# Out:
# 0.07543265306122449
# 0.2746500556366674
